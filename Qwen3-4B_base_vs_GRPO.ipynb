# %% [markdown]
# cloning lm_eval and installing dependencies

# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# %cd lm-evaluation-harness
# !pip install -e .
# Out:
# Cloning into 'lm-evaluation-harness'...
# remote: Enumerating objects: 60895, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 60895 (delta 67), reused 36 (delta 36), pack-reused 60807 (from 3)
# Receiving objects: 100% (60895/60895), 33.70 MiB | 18.63 MiB/s, done.
# Resolving deltas: 100% (41686/41686), done.
# /content/lm-evaluation-harness
# Obtaining file:///content/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 13.8 MB/s eta 0:00:00
# ...

# %%
# !pip install accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Comparison **gsm8k** task  (Qwen3-4B base mode vs Qwen3-4B grpo)

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=arefehRajabian/Qwen3-4B-Base-persian-math-grpo \
    --tasks gsm8k \
    --device cuda:0 \
    --batch_size 4 \
    --limit 50 \
    --log_samples \
    --output_path /kaggle/working/results
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2026-02-19:10:09:32 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:10:09:44 INFO     [_cli.run:378] Selected Tasks: ['gsm8k']
# 2026-02-19:10:09:46 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:10:09:46 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'arefehRajabian/Qwen3-4B-Base-persian-math-grpo'}
# ...

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=unsloth/Qwen3-4B-Base \
    --tasks gsm8k \
    --device cuda:0 \
    --batch_size 4 \
    --limit 50 \
    --log_samples \
    --output_path /kaggle/working/results
# Out:
# 2026-02-19:11:01:10 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:11:01:21 INFO     [_cli.run:378] Selected Tasks: ['gsm8k']
# 2026-02-19:11:01:25 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:11:01:25 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'unsloth/Qwen3-4B-Base'}
# 2026-02-19:11:01:35 INFO     [models.huggingface:161] Using device 'cuda:0'
# config.json: 100% 752/752 [00:00<00:00, 4.71MB/s]
# tokenizer_config.json: 5.43kB [00:00, 17.5MB/s]
# vocab.json: 2.78MB [00:00, 115MB/s]
# ...
# merges.txt: 1.67MB [00:00, 114MB/s]
# tokenizer.json: 100% 11.4M/11.4M [00:01<00:00, 9.00MB/s]
# added_tokens.json: 100% 707/707 [00:00<00:00, 4.81MB/s]
# special_tokens_map.json: 100% 617/617 [00:00<00:00, 3.21MB/s]
# ...

# %% [markdown]
# # Comparison **gsm8k_cot** task

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=arefehRajabian/Qwen3-4B-Base-persian-math-grpo \
    --tasks gsm8k_cot \
    --device cuda:0 \
    --batch_size 8 \
    --limit 50 \
    --log_samples \
    --output_path /content/persian-results3
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2026-02-19:09:11:51 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:09:12:02 INFO     [_cli.run:378] Selected Tasks: ['gsm8k_cot']
# 2026-02-19:09:12:04 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:09:12:04 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'arefehRajabian/qwen2.5-3b-persian-math-grpo'}
# ...

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=unsloth/Qwen3-4B-Base \
    --tasks gsm8k_cot \
    --device cuda:0 \
    --batch_size 4 \
    --limit 50 \
    --log_samples \
    --output_path /kaggle/working/results
# Out:
# 2026-02-19:11:09:35 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:11:09:44 INFO     [_cli.run:378] Selected Tasks: ['gsm8k_cot']
# 2026-02-19:11:09:46 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:11:09:46 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'unsloth/Qwen3-4B-Base'}
# 2026-02-19:11:09:50 INFO     [models.huggingface:161] Using device 'cuda:0'
# ...
# 2026-02-19:11:09:53 INFO     [models.huggingface:423] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda:0'}
# Loading weights: 100% 398/398 [00:02<00:00, 197.63it/s, Materializing param=model.norm.weight]
# 2026-02-19:11:10:00 INFO     [evaluator_utils:446] Selected tasks:
# ...

# %% [markdown]
# # Comparison **gsm8k_cot_zeroshot** task

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=arefehRajabian/Qwen3-4B-Base-persian-math-grpo \
    --tasks gsm8k_cot_zeroshot \
    --device cuda:0 \
    --batch_size 8 \
    --limit 50 \
    --log_samples \
    --output_path /content/persian-results4
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2026-02-19:09:24:42 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:09:24:53 INFO     [_cli.run:378] Selected Tasks: ['gsm8k_cot_zeroshot']
# 2026-02-19:09:24:54 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:09:24:54 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'arefehRajabian/qwen2.5-3b-persian-math-grpo'}
# ...

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=unsloth/Qwen3-4B-Base \
    --tasks gsm8k_cot_zeroshot \
    --device cuda:0 \
    --batch_size 4 \
    --limit 50 \
    --log_samples \
    --output_path /content/results
# Out:
# 2026-02-19:12:04:49 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:12:04:59 INFO     [_cli.run:378] Selected Tasks: ['gsm8k_cot_zeroshot']
# 2026-02-19:12:05:03 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:12:05:03 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'unsloth/Qwen3-4B-Base'}
# 2026-02-19:12:05:12 INFO     [models.huggingface:161] Using device 'cuda:0'
# config.json: 100% 752/752 [00:00<00:00, 2.73MB/s]
# tokenizer_config.json: 5.43kB [00:00, 13.3MB/s]
# vocab.json: 2.78MB [00:00, 109MB/s]
# merges.txt: 1.67MB [00:00, 132MB/s]
# tokenizer.json: 100% 11.4M/11.4M [00:01<00:00, 8.85MB/s]
# added_tokens.json: 100% 707/707 [00:00<00:00, 3.93MB/s]
# ...
# special_tokens_map.json: 100% 617/617 [00:00<00:00, 4.16MB/s]
# ...

# %% [markdown]
# # Comparison **gsm8k_cot_llama** task

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=arefehRajabian/Qwen3-4B-Base-persian-math-grpo \
    --tasks gsm8k_cot_llama \
    --device cuda:0 \
    --batch_size 8 \
    --limit 50 \
    --log_samples \
    --output_path /content/persian-results5
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2026-02-19:09:32:15 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:09:32:26 INFO     [_cli.run:378] Selected Tasks: ['gsm8k_cot_llama']
# 2026-02-19:09:32:28 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:09:32:28 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'arefehRajabian/qwen2.5-3b-persian-math-grpo'}
# ...

# %%
# !python -m lm_eval --model hf \
    --model_args pretrained=unsloth/Qwen3-4B-Base \
    --tasks gsm8k_cot_llama \
    --device cuda:0 \
    --batch_size 8 \
    --limit 50 \
    --log_samples \
    --output_path /content/persian-results
# Out:
# 2026-02-19:13:15:39 WARNING  [config.evaluate_config:281] --limit SHOULD ONLY BE USED FOR TESTING. REAL METRICS SHOULD NOT BE COMPUTED USING LIMIT.
# 2026-02-19:13:15:49 INFO     [_cli.run:378] Selected Tasks: ['gsm8k_cot_llama']
# 2026-02-19:13:15:54 INFO     [evaluator:213] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2026-02-19:13:15:54 INFO     [evaluator:238] Initializing hf model, with arguments: {'pretrained': 'unsloth/Qwen3-4B-Base'}
# 2026-02-19:13:16:04 INFO     [models.huggingface:161] Using device 'cuda:0'
# config.json: 100% 752/752 [00:00<00:00, 4.36MB/s]
# tokenizer_config.json: 5.43kB [00:00, 17.0MB/s]
# ...
# vocab.json: 2.78MB [00:00, 114MB/s]
# merges.txt: 1.67MB [00:00, 119MB/s]
# tokenizer.json: 100% 11.4M/11.4M [00:01<00:00, 8.99MB/s]
# added_tokens.json: 100% 707/707 [00:00<00:00, 4.85MB/s]
# special_tokens_map.json: 100% 617/617 [00:00<00:00, 4.45MB/s]
# ...
