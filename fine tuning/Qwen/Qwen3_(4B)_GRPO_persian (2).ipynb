# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your local device, follow [our guide](https://unsloth.ai/docs/get-started/install). This notebook is licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & how to save it

# %% [markdown]
# ### News

# %% [markdown]
# Train MoEs - DeepSeek, GLM, Qwen and gpt-oss 12x faster with 35% less VRAM. [Blog](https://unsloth.ai/docs/new/faster-moe)
#
# You can now train embedding models 1.8-3.3x faster with 20% less VRAM. [Blog](https://unsloth.ai/docs/new/embedding-finetuning)
#
# Ultra Long-Context Reinforcement Learning is here with 7x more context windows! [Blog](https://unsloth.ai/docs/new/grpo-long-context)
#
# 3x faster LLM training with 30% less VRAM and 500K context. [3x faster](https://unsloth.ai/docs/new/3x-faster-training-packing) • [500K Context](https://unsloth.ai/docs/new/500k-context-length-fine-tuning)
#
# New in Reinforcement Learning: [FP8 RL](https://unsloth.ai/docs/new/fp8-reinforcement-learning) • [Vision RL](https://unsloth.ai/docs/new/vision-reinforcement-learning-vlm-rl) • [Standby](https://unsloth.ai/docs/basics/memory-efficient-rl) • [gpt-oss RL](https://unsloth.ai/docs/new/gpt-oss-reinforcement-learning)
#
# Visit our docs for all our [model uploads](https://unsloth.ai/docs/get-started/unsloth-model-catalog) and [notebooks](https://unsloth.ai/docs/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1" # [NEW] Extra 30% context lengths!
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy, PIL; _numpy = f'numpy=={numpy.__version__}'; _pil = f'pillow=={PIL.__version__}'
    except: _numpy = "numpy"; _pil = "pillow"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    _vllm, _triton = ('vllm==0.9.2', 'triton==3.2.0') if is_t4 else ('vllm==0.15.1', 'triton')
    # !uv pip install -qqq --upgrade {_vllm} {_numpy} {_pil} torchvision bitsandbytes xformers unsloth
    # !uv pip install -qqq {_triton}
# !uv pip install transformers==4.56.2
# !uv pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Goal: To convert `Qwen3-4B-Base` into a reasoning model via GRPO by using OpenR1's Math dataset.
#
# We first pre fine-tune the model to make GRPO skip trying to match formatting - this speeds GRPO up.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-4B-Base",
    max_seq_length = max_seq_length,
    load_in_4bit = False, # False for LoRA 16bit
    fast_inference = True, # Enable vllm fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.9, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = lora_rank*2, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 02-16 16:00:07 [__init__.py:244] Automatically detected platform cuda.
# ERROR 02-16 16:00:09 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 02-16 16:00:20 [vllm_utils.py:723] Unsloth: Patching vLLM v1 graph capture
# INFO 02-16 16:00:20 [vllm_utils.py:752] Unsloth: Patching vLLM v0 graph capture
# ==((====))==  Unsloth 2026.2.1: Fast Qwen3 patching. Transformers: 4.56.2. vLLM: 0.9.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Standby mode is enabled. However your setting of `gpu_memory_utilization` will OOM.
# Changing `gpu_memory_utilization` to 0.8.
# Unsloth: vLLM loading unsloth/Qwen3-4B-Base with actual GPU utilization = 79.22%
# Unsloth: Your GPU has CUDA compute capability 7.5 with VRAM = 14.56 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 32.
# Unsloth: vLLM's KV Cache can use up to 4.44 GB. Also swap space = 0 GB.
# Unsloth: `cudagraph_mode` is not in `from vllm.config import CompilationConfig`
# Unsloth: Disabling `disable_cascade_attn` in vLLM to allow for better on policy RL!
# INFO 02-16 16:00:43 [config.py:841] This model supports multiple tasks: {'reward', 'classify', 'generate', 'embed'}. Defaulting to 'generate'.
# `torch_dtype` is deprecated! Use `dtype` instead!
# WARNING 02-16 16:00:43 [config.py:3371] Casting torch.bfloat16 to torch.float16.
# INFO 02-16 16:00:43 [config.py:1472] Using max model len 2048
# WARNING 02-16 16:00:43 [arg_utils.py:1735] Compute Capability < 8.0 is not supported by the V1 Engine. Falling back to V0.
# INFO 02-16 16:00:45 [config.py:2285] Chunked prefill is enabled with max_num_batched_tokens=4096.
# INFO 02-16 16:00:45 [llm_engine.py:230] Initializing a V0 LLM engine (v0.9.2) with config: model='unsloth/Qwen3-4B-Base', speculative_config=None, tokenizer='unsloth/Qwen3-4B-Base', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/Qwen3-4B-Base, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":[],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":4,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":true,"max_capture_size":32,"local_cache_dir":null}, use_cached_outputs=False,
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# INFO 02-16 16:00:47 [cuda.py:311] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 02-16 16:00:47 [cuda.py:360] Using XFormers backend.
# INFO 02-16 16:00:48 [parallel_state.py:1076] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# INFO 02-16 16:00:48 [model_runner.py:1171] Starting to load model unsloth/Qwen3-4B-Base...
# INFO 02-16 16:00:49 [weight_utils.py:292] Using model weights format ['*.safetensors']
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# INFO 02-16 16:03:48 [weight_utils.py:308] Time spent downloading weights for unsloth/Qwen3-4B-Base: 178.944192 seconds
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 02-16 16:04:22 [default_loader.py:272] Loading weights took 33.43 seconds
# INFO 02-16 16:04:22 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 02-16 16:04:23 [model_runner.py:1203] Model loading took 7.6765 GiB and 213.150788 seconds
# INFO 02-16 16:04:34 [worker.py:294] Memory profiling takes 10.53 seconds
# INFO 02-16 16:04:34 [worker.py:294] the current vLLM instance can use total_gpu_memory (14.56GiB) x gpu_memory_utilization (0.79) = 11.54GiB
# INFO 02-16 16:04:34 [worker.py:294] model weights take 7.68GiB; non_torch_memory takes 0.03GiB; PyTorch activation peak memory takes 0.31GiB; the rest of the memory reserved for KV Cache is 3.52GiB.
# INFO 02-16 16:04:35 [executor_base.py:113] # cuda blocks: 1602, # CPU blocks: 0
# INFO 02-16 16:04:35 [executor_base.py:118] Maximum concurrency for 2048 tokens per request: 12.52x
# INFO 02-16 16:04:35 [vllm_utils.py:757] Unsloth: Running patched vLLM v0 `capture_model`.
# INFO 02-16 16:04:35 [model_runner.py:1513] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes:   0%|          | 0/7 [00:00<?, ?it/s]
# INFO 02-16 16:04:47 [model_runner.py:1671] Graph capturing finished in 13 secs, took 0.10 GiB
# INFO 02-16 16:04:47 [vllm_utils.py:764] Unsloth: Patched vLLM v0 graph capture finished in 13 secs.
# INFO 02-16 16:04:49 [llm_engine.py:428] init engine (profile, create kv cache, warmup model) took 25.51 seconds
# Unsloth: Just some info: will skip parsing ['layer_norm2', 'ffn_norm', 'pre_feedforward_layernorm', 'post_layernorm', 'q_norm', 'norm2', 'post_attention_layernorm', 'norm1', 'post_feedforward_layernorm', 'layer_norm1', 'k_norm', 'norm', 'attention_norm', 'input_layernorm']
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of Qwen3ForCausalLM were not initialized from the model checkpoint at unsloth/Qwen3-4B-Base and are newly initialized: ['lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Performing substitution for additional_keys=set()
# Unsloth: Just some info: will skip parsing ['layer_norm2', 'ffn_norm', 'pre_feedforward_layernorm', 'post_layernorm', 'q_norm', 'norm2', 'post_attention_layernorm', 'norm1', 'cross_attn_input_layernorm', 'post_feedforward_layernorm', 'layer_norm1', 'k_norm', 'cross_attn_post_attention_layernorm', 'norm', 'attention_norm', 'input_layernorm']
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Unsloth 2026.2.1 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### GRPO chat template
# Since we're using a base model, we should set a chat template. You can make your own chat template as well!
# 1. DeepSeek uses `<think>` and `</think>`, but this is **not** necessary - you can customize it however you like!
# 2. A `system_prompt` is recommended to at least guide the model's responses.

# %%
reasoning_start = "<start_working_out>" # Acts as <think>
reasoning_end   = "<end_working_out>"   # Acts as </think>
solution_start  = "<SOLUTION>"
solution_end    = "</SOLUTION>"

system_prompt = \
f"""You are given a problem.
Think about the problem and provide your working out.
Place it between {reasoning_start} and {reasoning_end}.
Then, provide your solution between {solution_start}{solution_end}"""
system_prompt
# Out:
# 'You are given a problem.\nThink about the problem and provide your working out.\nPlace it between <start_working_out> and <end_working_out>.\nThen, provide your solution between <SOLUTION></SOLUTION>'

# %% [markdown]
# We create a simple chat template below. Notice `add_generation_prompt` includes prepending `<start_working_out>` to guide the model to start its reasoning process.

# %%
chat_template = \
    "{% if messages[0]['role'] == 'system' %}"\
        "{{ messages[0]['content'] + eos_token }}"\
        "{% set loop_messages = messages[1:] %}"\
    "{% else %}"\
        "{{ '{system_prompt}' + eos_token }}"\
        "{% set loop_messages = messages %}"\
    "{% endif %}"\
    "{% for message in loop_messages %}"\
        "{% if message['role'] == 'user' %}"\
            "{{ message['content'] }}"\
        "{% elif message['role'] == 'assistant' %}"\
            "{{ message['content'] + eos_token }}"\
        "{% endif %}"\
    "{% endfor %}"\
    "{% if add_generation_prompt %}{{ '{reasoning_start}' }}"\
    "{% endif %}"

# Replace with our specific template:
chat_template = chat_template\
    .replace("'{system_prompt}'",   f"'{system_prompt}'")\
    .replace("'{reasoning_start}'", f"'{reasoning_start}'")
tokenizer.chat_template = chat_template

# %% [markdown]
# Let's see how our chat template behaves on an example:

# %%
tokenizer.apply_chat_template([
    {"role" : "user", "content" : "What is 1+1?"},
    {"role" : "assistant", "content" : f"{reasoning_start}I think it's 2.{reasoning_end}{solution_start}2{solution_end}"},
    {"role" : "user", "content" : "What is 2+2?"},
], tokenize = False, add_generation_prompt = True)
# Out:
# "You are given a problem.\nThink about the problem and provide your working out.\nPlace it between <start_working_out> and <end_working_out>.\nThen, provide your solution between <SOLUTION></SOLUTION><|endoftext|>What is 1+1?<start_working_out>I think it's 2.<end_working_out><SOLUTION>2</SOLUTION><|endoftext|>What is 2+2?<start_working_out>"

# %% [markdown]
# ### Pre fine-tuning for formatting
# We now use a subset of NVIDIA's [Open Math Reasoning dataset](https://huggingface.co/datasets/nvidia/OpenMathReasoning) which was filtered to only include high quality DeepSeek R1 traces.
#
# We'll only filter ~59 or so examples to first "prime" / pre fine-tune the model to understand our custom GRPO formatting.

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np

dataset = load_dataset("unsloth/OpenMathReasoning-mini", split = "cot")
dataset = dataset.to_pandas()[
    ["expected_answer", "problem", "generated_solution"]
]

# Try converting to number - if not, replace with NaN
is_number = pd.to_numeric(pd.Series(dataset["expected_answer"]), errors = "coerce").notnull()
# Select only numbers
dataset = dataset.iloc[np.where(is_number)[0]]

dataset
# Out:
# README.md:   0%|          | 0.00/603 [00:00<?, ?B/s]
# data/cot-00000-of-00001.parquet:   0%|          | 0.00/106M [00:00<?, ?B/s]
# Generating cot split:   0%|          | 0/19252 [00:00<?, ? examples/s]
#       expected_answer                                            problem  \
# 0                  14  Given $\sqrt{x^2+165}-\sqrt{x^2-52}=7$ and $x$...
# 6                  -2  Find the value of the parameter $a$ for which ...
# 9                  18  What is the sum of all real numbers $x$ for wh...
# 13                  2  Evaluate the sum \(\sum_{n=1}^\infty \frac{\ph...
# 17                 30  What is the largest positive integer that divi...
# ...               ...                                                ...
# 19243             244  Let \( p \), \( q \), and \( r \) be the disti...
# 19245               1  A bug is on the $0$ of a number line. At any p...
# 19247               4  A bus left point X for point Y. Two hours late...
# 19248              18  Each interior angle of a regular n-gon measure...
# 19250          0.8960  Find the probability that the second blue resu...
#
#                                       generated_solution
# 0      <think>\nOkay, let's see. I need to solve the ...
# 6      <think>\nOkay, so I need to find the value of ...
# 9      <think>\nOkay, so I need to solve the equation...
# 13     <think>\nOkay, so I need to evaluate the infin...
# 17     <think>\nAlright, so I need to find the larges...
# ...                                                  ...
# 19243  <think>\nOkay, so I need to find the value of ...
# 19245  <think>\nOkay, so I have this problem where a ...
# 19247  <think>\nOkay, let's tackle this problem step ...
# 19248  <think>\nOkay, let's see. I need to find the n...
# 19250  <think>\nOkay, so I need to find the probabili...
#
# [7507 rows x 3 columns]

# %% [markdown]
# We have to format the dataset to follow our GRPO style formatting:

# %%
def format_dataset(x):
    expected_answer = x["expected_answer"]
    problem = x["problem"]

    # Remove generated <think> and </think>
    thoughts = x["generated_solution"]
    thoughts = thoughts.replace("<think>", "").replace("</think>", "")

    # Strip newlines on left and right
    thoughts = thoughts.strip()
    # Add our custom formatting
    final_prompt = \
        reasoning_start + thoughts + reasoning_end + \
        solution_start + expected_answer + solution_end
    return [
        {"role" : "system",    "content" : system_prompt},
        {"role" : "user",      "content" : problem},
        {"role" : "assistant", "content" : final_prompt},
    ]

dataset["Messages"] = dataset.apply(format_dataset, axis = 1)

# %% [markdown]
# Check to see if it worked:

# %%
tokenizer.apply_chat_template(dataset["Messages"][0], tokenize = False)
# Out:
# "You are given a problem.\nThink about the problem and provide your working out.\nPlace it between <start_working_out> and <end_working_out>.\nThen, provide your solution between <SOLUTION></SOLUTION><|endoftext|>Given $\\sqrt{x^2+165}-\\sqrt{x^2-52}=7$ and $x$ is positive, find all possible values of $x$.<start_working_out>Okay, let's see. I need to solve the equation √(x² + 165) - √(x² - 52) = 7, and find all positive values of x. Hmm, radicals can be tricky, but maybe if I can eliminate the square roots by squaring both sides. Let me try that.\n\nFirst, let me write down the equation again to make sure I have it right:\n\n√(x² + 165) - √(x² - 52) = 7.\n\nOkay, so the idea is to isolate one of the radicals and then square both sides. Let me try moving the second radical to the other side:\n\n√(x² + 165) = 7 + √(x² - 52).\n\nNow, if I square both sides, maybe I can get rid of the square roots. Let's do that:\n\n(√(x² + 165))² = (7 + √(x² - 52))².\n\nSimplifying the left side:\n\nx² + 165 = 49 + 14√(x² - 52) + (√(x² - 52))².\n\nThe right side is expanded using the formula (a + b)² = a² + 2ab + b². So the right side becomes 7² + 2*7*√(x² - 52) + (√(x² - 52))², which is 49 + 14√(x² - 52) + (x² - 52).\n\nSo putting it all together:\n\nx² + 165 = 49 + 14√(x² - 52) + x² - 52.\n\nHmm, let's simplify the right side. The x² terms will cancel out, right? Let's subtract x² from both sides:\n\n165 = 49 + 14√(x² - 52) - 52.\n\nSimplify the constants on the right:\n\n49 - 52 is -3, so:\n\n165 = -3 + 14√(x² - 52).\n\nNow, add 3 to both sides to isolate the radical term:\n\n165 + 3 = 14√(x² - 52).\n\nSo 168 = 14√(x² - 52).\n\nDivide both sides by 14:\n\n168 / 14 = √(x² - 52).\n\n12 = √(x² - 52).\n\nNow, square both sides again to eliminate the square root:\n\n12² = x² - 52.\n\n144 = x² - 52.\n\nAdd 52 to both sides:\n\n144 + 52 = x².\n\n196 = x².\n\nSo x = √196 = 14.\n\nBut wait, since the problem states that x is positive, we only take the positive root. So x = 14.\n\nBut hold on, when dealing with squaring equations, sometimes extraneous solutions can come up. I should check if this solution actually satisfies the original equation.\n\nLet's plug x = 14 back into the original equation:\n\n√(14² + 165) - √(14² - 52) = ?\n\nCalculate each term:\n\n14² is 196.\n\nSo first radical: √(196 + 165) = √361 = 19.\n\nSecond radical: √(196 - 52) = √144 = 12.\n\nSo 19 - 12 = 7, which is exactly the right-hand side. So yes, it checks out.\n\nTherefore, the only solution is x = 14. Since the problem says x is positive, we don't have to consider negative roots. So I think that's the answer.\nTo solve the equation \\(\\sqrt{x^2 + 165} - \\sqrt{x^2 - 52} = 7\\) for positive \\(x\\), we proceed as follows:\n\n1. Start with the given equation:\n   \\[\n   \\sqrt{x^2 + 165} - \\sqrt{x^2 - 52} = 7\n   \\]\n\n2. Isolate one of the square roots by moving \\(\\sqrt{x^2 - 52}\\) to the right side:\n   \\[\n   \\sqrt{x^2 + 165} = 7 + \\sqrt{x^2 - 52}\n   \\]\n\n3. Square both sides to eliminate the square root on the left:\n   \\[\n   (\\sqrt{x^2 + 165})^2 = (7 + \\sqrt{x^2 - 52})^2\n   \\]\n   Simplifying both sides, we get:\n   \\[\n   x^2 + 165 = 49 + 14\\sqrt{x^2 - 52} + (x^2 - 52)\n   \\]\n\n4. Combine like terms on the right side:\n   \\[\n   x^2 + 165 = x^2 - 52 + 49 + 14\\sqrt{x^2 - 52}\n   \\]\n   Simplifying further:\n   \\[\n   x^2 + 165 = x^2 - 3 + 14\\sqrt{x^2 - 52}\n   \\]\n\n5. Subtract \\(x^2\\) from both sides:\n   \\[\n   165 = -3 + 14\\sqrt{x^2 - 52}\n   \\]\n\n6. Add 3 to both sides to isolate the term with the square root:\n   \\[\n   168 = 14\\sqrt{x^2 - 52}\n   \\]\n\n7. Divide both sides by 14:\n   \\[\n   12 = \\sqrt{x^2 - 52}\n   \\]\n\n8. Square both sides again to eliminate the square root:\n   \\[\n   12^2 = x^2 - 52\n   \\]\n   Simplifying:\n   \\[\n   144 = x^2 - 52\n   \\]\n\n9. Add 52 to both sides to solve for \\(x^2\\):\n   \\[\n   196 = x^2\n   \\]\n\n10. Take the positive square root (since \\(x\\) is positive):\n    \\[\n    x = ...

# %% [markdown]
# Let's truncate the pre fine-tuning dataset to `max_seq_length/2` since we don't want too long reasoning traces.
#
# Note this might take 2 minutes!

# %%
dataset["N"] = dataset["Messages"].apply(lambda x: len(tokenizer.apply_chat_template(x)))

dataset = dataset.loc[dataset["N"] <= max_seq_length/2].copy()
dataset.shape
# Out:
# (59, 5)

# %% [markdown]
# We then tokenize the messages and convert it to a Hugging Face compatible dataset format:

# %%
from datasets import Dataset

dataset["text"] = tokenizer.apply_chat_template(dataset["Messages"].values.tolist(), tokenize = False)
dataset = Dataset.from_pandas(dataset)
dataset
# Out:
# Dataset({
#     features: ['expected_answer', 'problem', 'generated_solution', 'Messages', 'N', 'text', '__index_level_0__'],
#     num_rows: 59
# })

# %% [markdown]
# Let's now pre fine-tune the model so it follows our custom GRPO formatting!

# %%
from trl import SFTTrainer, SFTConfig
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 1, # Use GA to mimic batch size!
        warmup_steps = 5,
        num_train_epochs = 2, # Set this for 1 full training run.
        learning_rate = 2e-4, # Reduce to 2e-5 for long training runs
        logging_steps = 5,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none", # Use TrackIO/WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/59 [00:00<?, ? examples/s]
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 59 | Num Epochs = 2 | Total steps = 118
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 1 x 1) = 1
#  "-____-"     Trainable parameters = 66,060,288 of 4,088,528,384 (1.62% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='118' max='118' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [118/118 02:53, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.644600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.639900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.419500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.389800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.422000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.449700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.475300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.419300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.445600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.328500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.382400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.455200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.246700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.244700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.301900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.225700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.212000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.260700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.191500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.261000</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.255900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.218600</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.181400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=118, training_loss=0.34900056709677485, metrics={'train_runtime': 182.3415, 'train_samples_per_second': 0.647, 'train_steps_per_second': 0.647, 'total_flos': 2374193075607552.0, 'train_loss': 0.34900056709677485, 'epoch': 2.0})

# %% [markdown]
# Let's check if the model has learnt to follow the custom format:

# %%
text = tokenizer.apply_chat_template(
    dataset[0]["Messages"][:2],
    tokenize = False,
    add_generation_prompt = True, # Must add for generation
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 0,
    max_new_tokens = 1024,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# You are given a problem.
# Think about the problem and provide your working out.
# Place it between <start_working_out> and <end_working_out>.
# Then, provide your solution between <SOLUTION></SOLUTION><|endoftext|>Jenifer has 82 cents in pennies and nickels. Her younger brother mistook all her nickels for dimes and counted the total as $1.47. How many pennies does Jenifer have?<start_working_out>Okay, let's see. Jenifer has some pennies and nickels totaling 82 cents. But her brother thought all the nickels were dimes and counted the total as $1.47. I need to find out how many pennies she has. Hmm, let me break this down.
#
# First, I need to set up some equations. Let's say the number of pennies is P and the number of nickels is N. The value of the pennies is 1 cent each, and nickels are 5 cents each. So the total value equation would be:
#
# P + 5N = 82 cents
#
# But her brother thought all the nickels were dimes. Dimes are 10 cents each. So he counted the total as $1.47, which is 147 cents. So the equation based on his mistaken count would be:
#
# P + 10N = 147 cents
#
# Now I have two equations:
#
# 1) P + 5N = 82
# 2) P + 10N = 147
#
# I need to solve these two equations to find P. Let me subtract the first equation from the second to eliminate P. So subtracting equation 1 from equation 2:
#
# (P + 10N) - (P + 5N) = 147 - 82
#
# That simplifies to:
#
# 5N = 65
#
# Then divide both sides by 5:
#
# N = 13
#
# So there are 13 nickels. Now plug N back into the first equation to find P:
#
# P + 5(13) = 82
#
# 5*13 is 65, so:
#
# P + 65 = 82
#
# Subtract 65 from both sides:
#
# P = 17
#
# So Jenifer has 17 pennies. Let me check that. If she has 17 pennies and 13 nickels, that's 17 + 65 = 82 cents, which matches. Her brother thought the nickels were dimes, so 13 dimes would be 130 cents. Adding the 17 pennies gives 147 cents, which is $1.47. That checks out. So the answer should be 17 pennies.
# To solve the problem, we start by defining the variables:
# - Let \( P \) be the number of pennies.
# - Let \( N \) be the number of nickels.
#
# We know two things:
# 1. The total value of the pennies and nickels is 82 cents.
# 2. If all nickels were mistaken for dimes, the total value would be $1.47 (or 147 cents).
#
# We can set up the following system of equations based on this information:
# 1. \( P + 5N = 82 \)
# 2. \( P + 10N = 147 \)
#
# To find the number of pennies \( P \), we can eliminate \( P \) by subtracting the first equation from the second:
# \[
# (P + 10N) - (P + 5N) = 147 - 82
# \]
# This simplifies to:
# \[
# 5N = 65
# \]
# Solving for \( N \):
# \[
# N = \frac{65}{5} = 13
# \]
#
# Now that we know \( N = 13 \), we substitute this value back into the first equation to find \( P \):
# \[
# P + 5(13) = 82
# \]
# \[
# P + 65 = 82
# \]
# \[
# P = 82 - 65 = 17
# \]
#
# Thus, Jenifer has \(\boxed{17}\) pennies.<end_working_out><SOLUTION>17</SOLUTION><|endoftext|>

# %% [markdown]
# Yes it did follow the formatting! Great! Let's remove some items before the GRPO step

# %%
del dataset
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We're using Hugging Face's [Open R1 Math dataset](https://huggingface.co/datasets/open-r1/DAPO-Math-17k-Processed). You can also utilize OpenAI's famous [GSM8K dataset](https://huggingface.co/datasets/openai/gsm8k)

# %%
from datasets import load_dataset
dataset = load_dataset("AmirFazlollahi/pgsm8k",  split = "train")
dataset
# Out:
# Dataset({
#     features: ['question', 'answer', 'outright_answer'],
#     num_rows: 7473
# })

# %%
dataset = dataset.rename_column("question", "prompt")
dataset = dataset.rename_column("answer", "solution")

# %% [markdown]
# Let's look at the first row:

# %%
dataset[0]["prompt"]
# Out:
# ' ناتالیا در ماه آوریل به ۴۸ نفر از دوستانش کلیپس فروخت، و سپس در ماه مه نصف همان تعداد کلیپس را فروخت. ناتالیا در ماه آوریل و مه روی هم رفته چند کلیپس فروخت؟'

# %%
dataset[0]["solution"]
# Out:
# ' ناتالیا در ماه مه ۴۸/۲ = <<۴۸/۲=۲۴>>۲۴ کلیپ فروخت. ناتالیا در ماه آوریل و مه در مجموع ۴۸+۲۴ = <<۴۸+۲۴=۷۲>>۷۲ کلیپ فروخت. #### ۷۲'

# %% [markdown]
# In GSM8K, we notice all answers like about have a ####, so we extract it. But for the Open R1 dataset, we can skip the below.

# %%
def extract_hash_answer(text):
    if "####" not in text: return None
    return text.split("####")[1].strip()
    # return text
extract_hash_answer(dataset[0]["solution"])
# Out:
# '۷۲'

# %% [markdown]
# Let's map the dataset! and see the first row:

# %%
dataset = dataset.map(lambda x: {
    "prompt" : [
        {"role": "system", "content": system_prompt},
        {"role": "user",   "content": x["prompt"]},
    ],
    "answer": extract_hash_answer(x["solution"]),
})
dataset[0]
# Out:
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]
# {'prompt': [{'content': 'You are given a problem.\nThink about the problem and provide your working out.\nPlace it between <start_working_out> and <end_working_out>.\nThen, provide your solution between <SOLUTION></SOLUTION>',
#    'role': 'system'},
#   {'content': ' ناتالیا در ماه آوریل به ۴۸ نفر از دوستانش کلیپس فروخت، و سپس در ماه مه نصف همان تعداد کلیپس را فروخت. ناتالیا در ماه آوریل و مه روی هم رفته چند کلیپس فروخت؟',
#    'role': 'user'}],
#  'solution': ' ناتالیا در ماه مه ۴۸/۲ = <<۴۸/۲=۲۴>>۲۴ کلیپ فروخت. ناتالیا در ماه آوریل و مه در مجموع ۴۸+۲۴ = <<۴۸+۲۴=۷۲>>۷۲ کلیپ فروخت. #### ۷۲',
#  'outright_answer': '۷۲',
#  'answer': '۷۲'}

# %% [markdown]
# We create a regex format to match the reasoning sections and answers:

# %%
import re

# Add optional EOS token matching
solution_end_regex = r"</SOLUTION>[\s]{0,}" + \
    "(?:" + re.escape(tokenizer.eos_token) + ")?"

match_format = re.compile(
    rf"{reasoning_end}.*?"\
    rf"{solution_start}(.+?){solution_end_regex}"\
    rf"[\s]{{0,}}$",
    flags = re.MULTILINE | re.DOTALL
)
match_format
# Out:
# re.compile(r'<end_working_out>.*?<SOLUTION>(.+?)</SOLUTION>[\s]{0,}(?:<\|endoftext\|>)?[\s]{0,}$',
# re.MULTILINE|re.DOTALL|re.UNICODE)

# %% [markdown]
# We verify it works:

# %%
match_format.findall(
    "Let me think!<end_working_out>"\
    f"<SOLUTION>\n2\n</SOLUTION>",
)
# Out:
# ['\n2\n']

# %%
match_format.findall(
    "<start_working_out>Let me think!<end_working_out>"\
    f"<SOLUTION>  2  </SOLUTION>\n\n",
)
# Out:
# ['  2  ']

# %% [markdown]
# We now want to create a reward function to match the format exactly - we reward it with 3 points if it succeeds:

# %%
def match_format_exactly(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        # Match if format is seen exactly!
        if match_format.search(response) is not None: score += 3.0
        scores.append(score)
    return scores

# %% [markdown]
# If it fails, we want to reward the model if it at least follows the format partially, by counting each symbol:

# %%
def match_format_approximately(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        # Count how many keywords are seen - we penalize if too many!
        # If we see 1, then plus some points!

        # No need to reward <start_working_out> since we always prepend it!
        # score += 0.5 if response.count(reasoning_start) == 1 else -1.0
        score += 0.5 if response.count(reasoning_end)   == 1 else -1.0
        score += 0.5 if response.count(solution_start)  == 1 else -1.0
        score += 0.5 if response.count(solution_end)    == 1 else -1.0
        scores.append(score)
    return scores

# %% [markdown]
# Finally, we want to extract the generated answer, and reward or penalize it! We also reward it based on how close the answer is to the true one via ratios:

# %%
def check_answer(prompts, completions, answer, **kwargs):
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [
        guess.group(1)
        if (guess := match_format.search(r)) is not None else None \
        for r in responses
    ]

    scores = []
    for guess, true_answer in zip(extracted_responses, answer):
        score = 0
        if guess is None:
            scores.append(-2.0)
            continue
        # Correct answer gets 5 points!
        if guess == true_answer:
            score += 5.0
        # Match if spaces are seen, but less reward
        elif guess.strip() == true_answer.strip():
            score += 3.5
        else:
            # We also reward it if the answer is close via ratios!
            # Ie if the answer is within some range, reward it!
            try:
                ratio = float(guess) / float(true_answer)
                if   ratio >= 0.9 and ratio <= 1.1: score += 2.0
                elif ratio >= 0.8 and ratio <= 1.2: score += 1.5
                else: score -= 2.5 # Penalize wrong answers
            except:
                score -= 4.5 # Penalize
        scores.append(score)
    return scores

# %% [markdown]
# Also sometimes it might not be 1 number as the answer, but like a sentence for example "The solution is $20" -> we extract 20.
#
# We also remove possible commas for example as in 123,456

# %%
match_numbers = re.compile(
    solution_start + r".*?[\s]{0,}([-]?[\d\.\,]{1,})",
    flags = re.MULTILINE | re.DOTALL
)
print(match_numbers.findall("<SOLUTION>  0.34  </SOLUTION>"))
print(match_numbers.findall("<SOLUTION>  123,456  </SOLUTION>"))
print(match_numbers.findall("<SOLUTION>  -0.234  </SOLUTION>"))
print(match_numbers.findall("<SOLUTION>17</SOLUTION>"))
# Out:
# ['0.34']
# ['123,456']
# ['-0.234']
# ['17']

# %% [markdown]
# We now prepare our main function which will print out the generated responses and the true answer, along with another reward function which converts text to float via `float` and sees if it's the same.

# %%
global PRINTED_TIMES
PRINTED_TIMES = 0
global PRINT_EVERY_STEPS
PRINT_EVERY_STEPS = 5

def check_numbers(prompts, completions, answer, **kwargs):
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [
        guess.group(1)
        if (guess := match_numbers.search(r)) is not None else None \
        for r in responses
    ]

    scores = []
    # Print only every few steps
    global PRINTED_TIMES
    global PRINT_EVERY_STEPS
    if PRINTED_TIMES % PRINT_EVERY_STEPS == 0:
        print(
            '*'*20 + f"Question:\n{question}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}"
        )
    PRINTED_TIMES += 1

    for guess, true_answer in zip(extracted_responses, answer):
        if guess is None:
            scores.append(-2.5)
            continue
        # Convert to numbers
        try:
            true_answer = float(true_answer.strip())
            # Remove commas like in 123,456
            guess       = float(guess.strip().replace(",", ""))
            scores.append(3.5 if guess == true_answer else -1.5)
        except:
            scores.append(0)
            continue
    return scores

# %% [markdown]
# Get the top 90% prompt length so we don't accidentally truncate them!
#
# Ie we'll remove the top 10% long prompts.

# %%
tokenized = dataset.map(
    lambda x: {"tokens" : tokenizer.apply_chat_template(x["prompt"], add_generation_prompt = True, tokenize = True)},
    batched = True,
)
print(tokenizer.decode(tokenized[0]["tokens"]))
tokenized = tokenized.map(lambda x: {"L" : len(x["tokens"])})

import numpy as np
maximum_length = int(np.quantile(tokenized["L"], 0.9))
print("Max Length = ", maximum_length)

# Filter only samples smaller than 90% max length
dataset = dataset.select(np.where(np.array(tokenized["L"]) <= maximum_length)[0])
del tokenized
# Out:
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]
# You are given a problem.
# Think about the problem and provide your working out.
# Place it between <start_working_out> and <end_working_out>.
# Then, provide your solution between <SOLUTION></SOLUTION><|endoftext|> ناتالیا در ماه آوریل به ۴۸ نفر از دوستانش کلیپس فروخت، و سپس در ماه مه نصف همان تعداد کلیپس را فروخت. ناتالیا در ماه آوریل و مه روی هم رفته چند کلیپس فروخت؟<start_working_out>
# Map:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Max Length =  257

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
max_prompt_length = maximum_length + 1 # + 1 just in case!
max_completion_length = max_seq_length - max_prompt_length

from vllm import SamplingParams
vllm_sampling_params = SamplingParams(
    min_p = 0.1,
    top_p = 1.0,
    top_k = -1,
    seed = 3407,
    stop = [tokenizer.eos_token],
    include_stop_str_in_output = True,
)

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    vllm_sampling_params = vllm_sampling_params,
    temperature = 1.0,
    learning_rate = 5e-6,
    weight_decay = 0.001,
    warmup_ratio = 0.1,
    lr_scheduler_type = "linear",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 4, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_completion_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 100,
    save_steps = 100,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",

    # For optional training + evaluation
    # fp16_full_eval = True,
    # per_device_eval_batch_size = 4,
    # eval_accumulation_steps = 1,
    # eval_strategy = "steps",
    # eval_steps = 1,
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
# For optional training + evaluation
# new_dataset = dataset.train_test_split(test_size = 0.01)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        match_format_exactly,
        match_format_approximately,
        check_answer,
        check_numbers,
    ],
    args = training_args,
    train_dataset = dataset,

    # For optional training + evaluation
    # train_dataset = new_dataset["train"],
    # eval_dataset = new_dataset["test"],
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 6,732 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 1 x 1) = 4
#  "-____-"     Trainable parameters = 66,060,288 of 4,088,528,384 (1.62% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
# ********************Question:
#  پس از آزمایش‌ها در کالیفرنیا، تعداد کل موارد ابتلا به ویروس کرونا در یک روز خاص ۲۰۰۰ مورد مثبت ثبت شد. تعداد موارد در روز دوم ۵۰۰ مورد افزایش یافت و ۵۰ نفر بهبود یافتند. در روز سوم، تعداد کل موارد جدید با ۲۰۰ بهبود یافته به ۱۵۰۰ مورد رسید. تعداد کل موارد مثبت پس از روز سوم چقدر است؟
# Answer:
# ۳۷۵۰
# Response:
# این مسئله را به تفکیک رویدادها و جمع آوری اطلاعات مورد نیاز پیش برده‌ام:
#
# 1. **تحلیل اولین روز:** تعداد موارد مثبت ثبت شده در روز اول ۲۰۰۰ مورد بود.
# 2. **بررسی دومین روز:** در این روز تعداد موارد به ۵۰۰ افزایش داد، که نشان‌دهنده که بیشتر مبتلایان در نزدیکی روز اول شناسایی شده‌اند. همچنین، ۵۰ نفر بهبود یافتند. این اطلاعات به ما نشان می‌دهد که تعداد کل موارد غیر مبتلا در این روز ۵۰۰ - ۵۰ = ۴۵۰ نفر بود.
# 3. **تحلیل سومین روز:** در این روز، تعداد کل موارد با ۲۰۰ مورد بیمار جدید به ۱۵۰۰ نفر رسید. این مورد نشان‌دهنده افزایش در بیماری است، لذا، تعداد کل مبتلایان (بیماران موجود) در این روز برابر ۱۵۰۰ مورد است. به همین دلیل، تعداد کل افرادی که بالاتر از آن می‌زنید ۲۰۰ مورد بیمار جدید است.
# 4. **جمع‌آوری کلی:** برای حل مسئله، ما باید اعدادی که در هر روز ثبت شد و به رشد بیماری یا بهبود آن اشاره دارند را مقایسه کنیم:
#    - در روز اول: ۲۰۰۰ مورد
#    - در روز دوم: تعداد کل افراد برابر ۵۰۰ (به افزایش) + ۵۰ نفر بهبود یافته → ۵۵۰ افراد
#    - در روز سوم: ۱۵۰۰ مورد بیمار (با ۲۰۰ نفر جدید و دوربین بهبود)
#
# نتیجهٔ این کار پیشنهادی است که، تعداد کل موارد مثبت پس از روز سوم برابر ۱۵۰۰ مورد است. این تعداد همچنین با توصیه‌ای که تعداد افراد بهبود یافته کمتر از تمدید شده در روز سوم باشد، بازپروری می‌کند. بنابراین، به طور عمومی، کل موارد افزوده در روزهای احتمالی سپس تا روز سوم، ۱۵۰۰ مورد نتیجتهٔ شمار افزایش یافته را مشخص می‌کند.
# To determine the total number of confirmed positive cases after the third day, we need to follow the given data step by step:
#
# 1. **First Day:**
#    - Total confirmed cases on the first day: \(2000\) cases.
#
# 2. **Second Day:**
#    - Increase in cases compared to the first day: \(500\) cases.
#    - New total cases on the second day: \(2000 + 500 = 2500\) cases.
#    - Number of recoveries on the second day: \(50\) cases.
#    - Therefore, the number of active cases on the second day is: \(2500 - 50 = 2450\) cases.
#
# 3. **Third Day:**
#    - Increase in cases on the third day: \(200\) active cases.
#    - New total cases on the third day: \(2500 + 200 = 2700\) cases.
#    - Number of recoveries on the third day: \(200\) active cases recover.
#
# 4. **Total Confirmed Cases After the Third Day:**
#    - Active cases on the third day: \(2700 - 200 = 2500\) cases.
#    - Therefore, the total number of confirmed cases after the third day is: \(2700\) cases.
#
# Thus, the total number of confirmed positive cases after the third day is \(\boxed{2700}\).<end_working_out><SOLUTION>2700</SOLUTION>
# Extracted:
# 2700
#     <div>
#
#       <progress value='85' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 85/100 1:35:39 < 17:17, 0.01 it/s, Epoch 0.01/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / match_format_exactly / mean</th>
#       <th>rewards / match_format_exactly / std</th>
#       <th>rewards / match_format_approximately / mean</th>
#       <th>rewards / match_format_approximately / std</th>
#       <th>rewards / check_answer / mean</th>
#       <th>rewards / check_answer / std</th>
#       <th>rewards / check_numbers / mean</th>
#       <th>rewards / check_numbers / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.232600</td>
#       <td>2.000000</td>
#       <td>7.427427</td>
#       <td>1198.250000</td>
#       <td>914.000000</td>
#       <td>1790.000000</td>
#       <td>0.250000</td>
#       <td>1001.000000</td>
#       <td>914.000000</td>
#       <td>1129.000000</td>
#       <td>0.094714</td>
#       <td>2.250000</td>
#       <td>1.500000</td>
#       <td>0.375000</td>
#       <td>2.250000</td>
#       <td>-0.125000</td>
#       <td>2.462214</td>
#       <td>-0.500000</td>
#       <td>2.708013</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.219900</td>
#       <td>1.250000</td>
#       <td>10.103630</td>
#       <td>1345.250000</td>
#       <td>981.000000</td>
#       <td>1790.000000</td>
#       <td>0.250000</td>
#       <td>1197.000000</td>
#       <td>981.000000</td>
#       <td>1583.000000</td>
#       <td>0.230482</td>
#       <td>1.500000</td>
#       <td>1.732051</td>
#       <td>-0.750000</td>
#       <td>2.598076</td>
#       <td>0.000000</td>
#       <td>2.309401</td>
#       <td>0.500000</td>
#       <td>3.464102</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.052600</td>
#       <td>-0.125000</td>
#       <td>7.498611</td>
#       <td>1109.500000</td>
#       <td>600.000000</td>
#       <td>1790.000000</td>
#       <td>0.250000</td>
#       <td>882.666687</td>
#       <td>600.000000</td>
#       <td>1265.000000</td>
#       <td>0.064379</td>
#       <td>1.500000</td>
#       <td>1.732051</td>
#       <td>0.000000</td>
#       <td>2.121320</td>
#       <td>-1.125000</td>
#       <td>2.096624</td>
#       <td>-0.500000</td>
#       <td>2.708013</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.180100</td>
#       <td>1.875000</td>
#       <td>5.735489</td>
#       <td>1285.000000</td>
#       <td>718.000000</td>
#       <td>1660.000000</td>
#       <td>0.000000</td>
#       <td>1285.000000</td>
#       <td>718.000000</td>
#       <td>1660.000000</td>
#       <td>0.114901</td>
#       <td>2.250000</td>
#       <td>1.500000</td>
#       <td>1.125000</td>
#       <td>0.750000</td>
#       <td>-1.250000</td>
#       <td>2.179450</td>
#       <td>-0.250000</td>
#       <td>2.500000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.105200</td>
#       <td>1.250000</td>
#       <td>10.103630</td>
#       <td>961.750000</td>
#       <td>367.000000</td>
#       <td>1790.000000</td>
#       <td>0.250000</td>
#       <td>685.666687</td>
#       <td>367.000000</td>
#       <td>867.000000</td>
#       <td>0.110278</td>
#       <td>1.500000</td>
#       <td>1.732051</td>
#       <td>-0.750000</td>
#       <td>2.598076</td>
#       <td>0.000000</td>
#       <td>2.309401</td>
#       <td>0.500000</td>
#       <td>3.464102</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.122200</td>
#       <td>5.250000</td>
#       <td>5.484828</td>
#       <td>805.500000</td>
#       <td>586.000000</td>
#       <td>1016.000000</td>
#       <td>0.000000</td>
#       <td>805.500000</td>
#       <td>586.000000</td>
#       <td>1016.000000</td>
#       <td>0.199629</td>
#       <td>3.000000</td>
#       <td>0.000000</td>
#       <td>1.500000</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>2.598076</td>
#       <td>1.000000</td>
#       <td>2.886751</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.193400</td>
#       <td>3.500000</td>
#       <td>8.356634</td>
#       <td>736.250000</td>
#       <td>485.000000</td>
#       <td>1130.000000</td>
#       <td>0.000000</td>
#       <td>736.250000</td>
#       <td>485.000000</td>
#       <td>1130.000000</td>
#       <td>0.152007</td>
#       <td>1.500000</td>
#       <td>1.732051</td>
#       <td>0.000000</td>
#       <td>2.121320</td>
#       <td>0.000000</td>
#       <td>2.309401</td>
#       <td>2.000000</td>
#       <td>3.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.227100</td>
#       <td>-1.125000</td>
#       <td>8.320407</td>
#       <td>1322.250000</td>
#       <td>851.000000</td>
#       <td>1678.000000</td>
#       <td>0.000000</td>
#       <td>1322.250000</td>
#       <td>851.000000</td>
#       <td>1678.000000</td>
#       <td>0.087566</td>
#       <td>1.500000</td>
#       <td>1.732051</td>
#       <td>-0.750000</td>
#       <td>2.598076</td>
#       <td>-1.125000</td>
#       <td>2.096624</td>
#       <td>-0.750000</td>
#       <td>2.872281</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>-0.066400</td>
#       <td>6.625000</td>
#       <td>6.750000</td>
#       <td>480.000000</td>
#       <td>416.000000</td>
#       <td>563.000000</td>
#       <td>0.000000</td>
#       <td>480.000000</td>
#       <td>416.000000</td>
#       <td>563.000000</td>
#       <td>0.220245</td>
#       <td>2.250000</td>
#       <td>1.500000</td>
#       <td>1.125000</td>
#       <td>0.750000</td>
#       <td>1.000000</td>
#       <td>2.000000</td>
#       <td>2.250000</td>
#       <td>2.500000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.038800</td>
#       <td>-1.750000</td>
#       <td>7.942502</td>
#       <td>1005.750000</td>
#       <td>320.000000</td>
#       <td>1790.000000</td>
#       <td>0.250000</td>
#       <td>744.333374</td>
#       <td>320.000000</td>
#       <td>1059.000000</td>
#       <td>0.103066</td>
#       <td>0.750000</td>
#       <td>1.500000</td>
#       <td>-0.750000</td>
#       <td>1.936492</td>
#       <td>-1.000000</td>
#       <td>2.000000</td>
#       <td>-0.750000</td>
#       <td>2.872281</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000200</td>
#       <td>10.000000</td>
#       <td>0.000000</td>
#       <td>593.250000</td>
#       <td>515.000000</td>
#       <td>779.000000</td>
#       <td>0.000000</td>
#       <td>593.250000</td>
#       <td>515.000000</td>
#       <td>779.000000</td>
#       <td>0.195584</td>
#       <td>3.000000</td>
#       <td>0.000000</td>
#       <td>1.500000</td>
#       <td>0.000000</td>
#       <td>2.000000</td>
#       <td>0.000000</td>
#       <td>3.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>-0.116300</td>
#       <td>6.625000</td>
#       <td>6.750000</td>
#       <td>946.250000</td>
#       <td>726.000000</td>
#       <td>1413.000000</td>
#       <td>0.000000</td>
#       <td>946.250000</td>
#       <td>726.000000</td>
#       <td>1413.000000</td>
#       <td>0.090419</td>
#       <td>2.250000</td>
#       <td>1.500000</td>
#       <td>1.125000</td>
#       <td>0.750000</td>
#       <td>1.000000</td>
#       <td>2.000000</td>
#       <td>2.250000</td>
#       <td>2.500000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>-0.265500</td>
#       <td>6.375000</td>
#       <td>7.250000</td>
#       <td>520.750000</td>
#       <td>244.000000</td>
#       <td>807.000000</td>
#       <td>0.000000</td>
#       <td>520.750000</td>
#       <td>244.000000</td>
#       <td>807.000000</td>
#       <td>0.180984</td>
#       <td>2.250000</td>
#       <td>1.500000</td>
#       <td>1.125000</td>
#       <td>0.750000</td>
#       <td>1.000000</td>
#       <td>2.000000</td>
#       <td>2.000000</td>
#       <td>3.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.105700</td>
#       <td>2.250000</td>
#       <td>9.096703</td>
#       <td>1043.250000</td>
#       <td>865.000000</td>
#       <td>1430.000000</td>
#       <td>0.000000</td>
#       <td>1043.250000</td>
#       <td>865.00000
# ********************Question:
#  سم شش رقم بیشتر از کارلوس از عدد پی حفظ کرد. مینا شش برابر کارلوس از عدد پی حفظ کرد. اگر مینا ۲۴ رقم از عدد پی را حفظ کرده باشد، سم چند رقم را حفظ کرده است؟
# Answer:
# ۱۰
# Response:
# Okay, let's try to solve this problem step by step. The problem is about a person named Saeed who memorized his six-digit phone number, which is larger than Carlos's. Minna memorized six times Carlos's phone number. If Minna remembered 24 digits of the number π (pi), how many digits did Saeed memorize? Hmm, wait, the question seems to have some keywords that might be confusing. Let me dissect it carefully.
#
# First, the key parts: Saeed's phone number is a six-digit number, larger than Carlos's. Minna memorized six times Carlos's number. But then it mentions Minna remembered 24 digits of π. Wait a second, that doesn't seem right. How can Minna remember a multiple of Carlos's phone number, which is six digits long, but also remember 24 digits of π? That doesn't add up.
#
# Wait, maybe there's a trick here. Maybe the "number of digits" refers to something else. Because statistically, π has an infinite number of digits, but when they say "memorize" 24 digits of π, it's not possible unless they're referring to a few digits. But the problem states that Minna memorized six times Carlos's number. If they're talking about the same thing, then maybe Carlos's number has 4 digits, so six times that would be 24 digits. But the problem says Saeed's number is six digits, which is larger than Carlos's. So Carlos's number must be a 4-digit number. Therefore, Saeed's number is 6 digits, which is larger than Carlos's 4-digit number. So six times 4 would be 24, matching Minna's memory. Therefore, Saeed memorized 6 digits, since the problem states he had his six-digit phone number. So the answer should be six. But let me confirm again.
#
# The problem says: Saeed's phone number is a six-digit number larger than Carlos's. Minna memorized six times Carlos's phone number. If Minna memorized 24 digits of π, how many digits did Saeed memorize? So, the "digits" refer to the number of digits in Carlos's phone number. So if Carlos's number is 4 digits, then six times that is 24 digits. Therefore, Saeed's number is 6 digits. So Saeed memorized 6 digits. The answer is six.
#
# Wait, but the problem mentions both Saeed memorizing his six-digit phone number and Minna memorizing six times Carlos's number. So Saeed's number is the 6-digit phone number he memorized. So the answer is six. Therefore, the answer is six. Let me check again with the original problem statement.
#
# Okay, the problem is about their phone numbers and the number of digits they can remember. So Saeed's phone number is a six-digit number, larger than Carlos's. Minna memorized six times Carlos's number. If Minna remembered 24 digits of π, how many digits did Saeed memorize? So the "six times Carlos's number" refers to the digits of Carlos's number. So if Carlos's number is 4 digits, then six times that is 24 digits. Therefore, Saeed memorized a six-digit phone number, which is six digits. So the answer should be six. Therefore, the answer is six.
# To solve the problem, let's break it down step by step:
#
# 1. Identify the key information given:
#    - Saeed's phone number is a six-digit number, larger than Carlos's.
#    - Minna memorized six times Carlos's phone number.
#    - Minna memorized 24 digits of the number π.
#
# 2. Define variables:
#    - Let \( C \) be the number of digits in Carlos's phone number.
#    - Since Minna memorized six times Carlos's phone number, she memorized \( 6C \) digits.
#    - We know that Minna memorized 24 digits of π.
#
# 3. Set up the equation:
#    - According to the problem, \( 6C = 24 \).
#
# 4. Solve for \( C \):
#    \[
#    6C = 24
#    \]
#    \[
#    C = \frac{24}{6} = 4
#    \]
#    So, Carlos's phone number has 4 digits.
#
# 5. Determine the number of digits Saeed memorized:
#    - The problem states that Saeed's phone number is a six-digit number.
#    - Therefore, Saeed memorized 6 digits.
#
# Thus, the number of digits Saeed memorized is \(\boxed{6}\).<end_working_out><SOLUTION>6</SOLUTION>
# Extracted:
# 6
# ********************Question:
#  جان از ارتفاع ۴۰۰ فوت شروع می‌کند. او به مدت ۵ دقیقه با سرعت ۱۰ فوت در دقیقه به سمت پایین حرکت می‌کند. ارتفاع او اکنون چقدر است؟
# Answer:
# ۳۵۰
# Response:
# خب، دوست عزیز. جان از ۴۰۰ فوت ارتفاع شروع کرده. بینشتمون، او ۵ دقیقه هست که تیمونه دنبال آذقنانه به سمت پایین می‌نوێت. این بارون، سرعت حرکتیش ۱۰ فوت برای هر دقیقه. چون لازمه نرم کردن: نگران (تأویلی)ه، مشخصه اندازه این ۵ دقیقه داده شده.
#
# پس باشه یادآوري کماند، انگاره که خوبه، واسه حلینه از این فکر  نمیکوم که ارتفاع لودني درخواست این مسئله مثبته نه منفی. بنابراین، ما فقط مسافتی که او درجه بندی کرده، محاسبه کنیم. ۵ دقیقه ضرب در ۱۰ فوت، یعنی حاصلی برابر ۵۰یکی فوت در راه اندازی، می‌کافی که اون.
#
# حالا، مفروشون نورید که، شروع ارتفاعش ۴۰۰، دیگه کمینه ۵۰ فوت که سائبی فشار داد یعنی. پس، محاسبه جواب این، ۴۰۰ با کم کردن ۵۰ که ۳۵۰ فوت است. جیب وجود. بهم گفت، جان الان روی ۳۵۰ فوت است.
# و دست کم هر حرفی که اینطور بازمیکنه. شایدیمیه چو لازمه رو بگیم حداقل اونو نرم کنیم، ولی این یه تعریف کاملا واضح؟ولی کاملا واضح، ۵۰. کولَرامیده منفی نمیشه. لذا جواب هست ۳۵۰ فوت.
# </start_working_out><end_working_out> To determine the new height of Jan after descending for 5 minutes at a speed of 10 feet per minute from an initial height of 400 feet, we can follow these steps:
#
# 1. Calculate the total distance Jan descends in 5 minutes.
#    \[
#    \text{Distance} = \text{Speed} \times \text{Time} = 10 \, \text{feet/minute} \times 5 \, \text{minutes} = 50 \, \text{feet}
#    \]
#
# 2. Subtract the distance descended from the initial height to find the new height.
#    \[
#    \text{New Height} = \text{Initial Height} - \text{Distance Descended} = 400 \, \text{feet} - 50 \, \text{feet} = 350 \, \text{feet}
#    \]
#
# Therefore, Jan's new height is \(\boxed{350}\) feet.<SOLUTION>350</SOLUTION>
# Extracted:
# 350
# ********************Question:
# یک مغازه چای شیر دیروز توانست در مجموع ۵۰ فنجان چای شیر بفروشد. دو پنجم فروش آنها طعم خربزه زمستانی، سه دهم طعم اوکیناوا و بقیه طعم شکلات است. آنها دیروز چند فنجان چای شیر با طعم شکلات توانستند بفروشند؟
# Answer:
# ۱۵
# Response:
# امروز سوالتون رو میخوام بفرسم تا بزارم خیلی از دوستانتون خیلی خوشحال بشن خیلی درسته اینو با خیلی راحت حل میشه لطفا خوب بفرمایید عجله نکنید چون اون صفحات داره رنگ درست میشن هرچند گیجی نکنید و احترام
#
# خب متوجه شدم تازه تغییر کارتونو اینجا دیدم خس خواب دارید
#
# خب بنده میگم وقتی دو صفحه رو میگیرید که هر کدام دو صفحه دارند و خودشون هرکدوم یک صفحه رو تغییر میکنن و بعد یکم هارمون است تا دوباره دو صفحه باشه. بنده فکر میکنبد محاسبه روتم ولی برسمه؟
#
# در واقع اگر هر صفحه خودش یک جواب رو تصمیم میگیره و بعد اینجأتکنون ما دو تکمیل داریم خ بقیه رو گرفته اما همچنین اگر دو نوعی از انوگهان را گرفتیم این پاسخ میتونه ازلغزته تمام توابع جامع میشه. پس هرکجا گفت‌نشون مشكل، یعنی همون‌طور که اگر انواد ساکم‌ Mẹ را هم آ Özel repo یا هر نوعی از validate pain Finder و فرض کنیم که آدم بیشترین چشمه‌هابه نظر میرسه که دو صفحه دیون خیلی زیاده است واسه وقت میگید.
# از در مهمترین چیزهای فرانس(نه خوش‌بین، بله دستن خوب بفرستون)میتونه از مشخصات رو بلندترم بذارن. اگر بدونیم که هر صفحه دارن یکی تا بیگ دینشونه، ولی دسته برای every Blogger بگو، مهمترین چیزی که هنوز حسونم می‌بین میشه. مثلا لولو، کاربران تازجن را میدانست.
#
# اگر این ۲ صفحه رو بگیرین، اولین صحبتی که می‌تونه هستش، طولید کوتاه رو داشته، بدونن که میشه اینکه فرض مشخصات اولا\پس اگر صفحه نمیخواید بیشتر دیدن تم بکتی، یعنی ریشه دخشه این شخصیت ما، یعنی آ-solvingه براتو پیشنهاد میکنم برای فشار خیلی هادی جایی غمی یعنی که شما همون الان فقط دوس‌ایده‌اشون هستش. توی من هر موضعیت را هرچقدر کمیت بجزصورت $۲0$ هد میکنین، موضعیت نظرده‌های شما که هم بودن، واجد دو صفحه، در فضای ارائهش رو می‌تونن غیره بگیرن. بارها اتمج داخل یکوی بسیاری از اصغر هد،, دیگه احتمالاتش هم، اگر فرض کنین که تمام  ${۲n}$ های بزرگ کمپانی که میشه از توزیع جمعیکنم،, فرض کنم‌مایه، اومد که این روشی هست، که هر کس غیربرندی میخواید، هم هم،, ورام دو مبحثی اومده مار را طیف میشه. از نظر شما ماهیت این ۱۰۰ را می‌دانه
#
# در حال حاضر، داده‌ها زین، توی روبارفیت، (این یعنی شهرم میتونه از دیگریچندRange؟ اون‌گه، به طور صحیح می‌توان‌بیشترین آخرین	cursor شهر هم این حالت‌های احتمالی دسته‌یه) سعی می‌کنم به‌صورتی میانگین‌ها بوده. مثلا برای‌هر تکمیل‌ ‎باهم ‌(محمد)؛ یا ۵۲ <= صفحهها زده‌وجود داشته باشه.
#
# در حالی که می‌تونه از اون‌طرف احتمال‌‎چیزی‌میان میزان بشه به‌طوری که اگر‌او، واقعا شش آورد از یه$, لحظات ۱) میلیون‌امونباناسب‌توان سین     اما اگر در نگاه‌شدن شخص با توجه به ۲ صفحه، اون دیدم یه‌میو بره ارائه‌بودن‌توان همین‌. نزدیک    $۵۷۶$، میشود خوب‌تر شما باید ۲ صفحه برات انسان‌ها نوشت. ۲ شماره مستحکم‌به‌لزوم می‌تونید تا همیتا\-. مکان نویسی براتو میشه‌به صورتی‌که اولین‌ضرب اول-site بوده، به‌صورتی‌که یک‌گتون، حد و مقدار خاص ۲ منطقه‌تورواردن، هویت‌میکند.
#
# حالا بریم به المساله ریاضی. فرض کنید دوباره ۵۰ مادو در صندوق وجود دارد. اگر سهمی از این مادو خاختارخ جمش آمده باشد، (به طوری که حسابشون میشه) دوتمان مگه همین‌. ۵۰ اونه دوشه که قراره آسیبا شه مبیعتقد باشین دوتاسرغل میلکنه. همون‌وقت‌که ویژگی‌ش‌مثال‌دوسباسته‌چون‌نسبت‌ای‌است. هنوز که بگم بنترت سؤالیه. سوالش اینه که با توجه به طعم‌ها رادارن‌زیادی‌دریو در فروش‌دونه،‌مثل‌راهنمایی‌ رو ادامه
# در مغازه چای شیر، مجموع فروش ۵۰ فنجان چای شیر بود. از این فنجان‌ها:
#
# - دو پنجم (�
# Extracted:
# None
# ********************Question:
#  آقای ری ۱۰۰ مشتری در بازار ماهی‌فروشی‌اش منتظر دارد. او ۱۰ ماهی تن دارد که هر کدام ۲۰۰ پوند وزن دارند. هر مشتری ۲۵ پوند ماهی تن می‌خواهد. فروشگاه آقای ری بر اساس اولویت ورود است. چند مشتری بدون ماهی به خانه می‌روند؟
# Answer:
# ۲۰
# Response:
# Okay, let's see. The problem says that there are 100 customers waiting at Mr. Riy's fish shop. He has 10 fish tank, each weighing 200 pounds. Each customer wants 25 pounds of fish. The shop operates on a first-come-first-served basis. The question is asking how many customers will leave empty-handed, meaning they won't get their desired amount of fish.
#
# First, I need to figure out the total amount of fish available. Since there are 10 fish tanks each weighing 200 pounds, the total fish Mr. Riy has is 10 tanks multiplied by 200 pounds per tank. Let me calculate that: 10 * 200 = 2000 pounds. So, he has 2000 pounds of fish in total.
#
# Each customer wants 25 pounds. To find out how many customers can be served, I need to divide the total fish by the amount each customer wants. So, 2000 divided by 25. Let me compute that. 2000 ÷ 25. Hmm, 25 times 80 is 2000. So, 2000 ÷ 25 = 80. Therefore, Mr. Riy can serve 80 customers with his total fish.
#
# Now, since there are 100 customers waiting, and he can only serve 80, the remaining customers won't get any fish. So, the number of customers left empty-handed is 100 minus 80. 100 - 80 = 20. Therefore, 20 customers will leave without any fish.
#
# Wait, let me check that again to make sure. The problem states that each customer wants 25 pounds. Each tank is 200 pounds, so one tank can serve 200 / 25 = 8 customers. Since there are 10 tanks, the total number of customers that can be served is 10 tanks * 8 customers per tank = 80 customers. That checks out.
#
# So, 80 can be served, 100 total - 80 = 20. Yep, that makes sense. The answer should be 20.
# To determine how many customers will leave without getting any fish, we need to follow these steps:
#
# 1. Calculate the total amount of fish available.
# 2. Determine how many customers can be served with the available fish.
# 3. Subtract the number of customers that can be served from the total number of customers to find the number of customers who will leave empty-handed.
#
# First, we calculate the total amount of fish available. Mr. Riy has 10 fish tanks, each weighing 200 pounds:
# \[
# 10 \times 200 = 2000 \text{ pounds}
# \]
#
# Next, we determine how many customers can be served with the total fish. Each customer wants 25 pounds of fish:
# \[
# \frac{2000}{25} = 80 \text{ customers}
# \]
#
# Since there are 100 customers waiting, the number of customers who will leave without any fish is:
# \[
# 100 - 80 = 20
# \]
#
# Thus, the number of customers who will leave empty-handed is \(\boxed{20}\).<end_working_out><SOLUTION>20</SOLUTION>
# Extracted:
# 20
# ********************Question:
# لیلا تقریباً هر هفته کیک می‌خورد. هفته‌ی گذشته، او دوشنبه ۶ کیک، جمعه ۹ کیک و شنبه، سه برابر تعداد کیک‌هایی که دوشنبه خورده بود، کیک خورد. لیلا چند کیک می‌خورد؟
# Answer:
# ۳۳
# Response:
# Okay, let's try to figure out how many cookies Laila ate last week. The problem says she almost eats cookies every week. Last week, on Tuesday she ate 6 cookies, Saturday she ate 9 cookies, and on Sunday she ate three times as many cookies as she did on Tuesday. Hmm, maybe I should start by writing down what we know.
#
# So, Tuesday's cookies are 6. Saturday's are 9. Then Sunday's is three times Tuesday's. Let me calculate that. Three times 6 is 18. So Sunday is 18 cookies.
#
# Wait, does the problem mention any other days? The problem only gives information for Tuesday, Saturday, and Sunday. Doesn't mention Wednesday, Thursday, or Friday. If that's the case, maybe she only ate on those three days. So adding them up. Let me check the numbers: 6 + 9 + 18. Let's add 6 and 9 first, which is 15. Then add 18 to that, so 15 + 18. Hmm, 15 plus 10 is 25, plus 8 more would be 33.
#
# Wait, let me recalculate: 6 + 9 is 15, then 15 + 18. Let's do it step by step. 15 plus 10 is 25, plus 8 more is 33. Yeah, she ate 33 cookies in total last week. Is there anything else? The problem said she almost eats cookies every week, but that part might just be extra information for context. The key part is the days mentioned: Tuesday, Saturday, and Sunday. So the answer should be 33. I don't think there's a trick here. Let me make sure I didn't miss any details. The problem states she almost eats cookies every week, but in this specific instance, she only ate on three days. So the total is 6 + 9 + 18 = 33. Yep, that seems right. I think 33 is the answer.
# To determine the total number of cookies Laila ate last week, we start by noting the information provided:
#
# - On Tuesday, she ate 6 cookies.
# - On Saturday, she ate 9 cookies.
# - On Sunday, she ate three times the number of cookies she ate on Tuesday.
#
# First, we calculate the number of cookies eaten on Sunday:
# \[ 3 \times 6 = 18 \]
#
# Next, we sum the cookies eaten on Tuesday, Saturday, and Sunday:
# \[ 6 + 9 + 18 \]
#
# Adding these values step-by-step:
# \[ 6 + 9 = 15 \]
# \[ 15 + 18 = 33 \]
#
# Therefore, the total number of cookies Laila ate last week is:
# \[
# \boxed{33}
# \]<end_working_out><SOLUTION>33</SOLUTION>
# Extracted:
# 33
# ********************Question:
#  الیزا ۲۰۰ حلقه زینتی می‌خرد تا در مغازه محلی‌شان بفروشد، دو برابر تعداد موجود. مادرش پس از فروش ۳/۴ کل موجودی، ۳۰۰ حلقه زینتی دیگر می‌خرد و پس از سه روز، ۱۵۰ حلقه می‌فروشد. تعداد کل حلقه‌های زینتی باقی مانده در مغازه چقدر است؟
# Answer:
# ۲۲۵
# Response:
# Okay, let's try to solve this problem. I need to figure out how many decorative bracelets are left in the store. The problem starts by saying Eliza buys 200 bracelets. Then it mentions something about being twice the amount available. Wait, maybe she bought twice as many as were already there? So if there were some number x, then she bought 2x. But then it says she bought 200. So 2x must be 200. Therefore, x would be 100. So initially, there were 100 bracelets, and then she adds 200, making it 300. Then her mom sells 3/4 of the total after she buys more. So 3/4 of 300 is 225, which means 75 are left after selling. Then her mom buys another 300 and sells 150. So 75 + 300 is 375, minus 150 is 225. So the answer should be 225. Let me check if I interpreted the problem correctly. Eliza buys twice the amount available, which would be half what she bought, right? Wait, no, if twice the amount available is 200, then the original amount was 100. So adding that 200 is 300. Then 3/4 sold is 225 left. Plus the 300 she bought earlier (which is after the 200 was already there) so 300+300=600. Then subtract 150 from 600 to get 450. Wait, that contradicts my previous answer. So maybe I made a mistake with the 3/4 part. The problem says that after Eliza bought 200, which is twice the initial amount, then her mom sold 3/4 of the total. So the total at that point is 100 (initial) + 200 = 300. Sold 3/4 of 300 is 225. Then she buys another 300, making it 525. Then she sells 150, leaving 525 - 150 = 375. So the second method gives 375. The first method was wrong because after Eliza's purchase, the total was 300, and selling 3/4 removes 225, leaving 75. Then adding 300 (which is the mother's purchase) gives 375, then subtracting 150 more sold is 225. Oh, wait, the confusion here is whether the 300 Eliza bought is in addition to the initial ones or if it's the twice the original. The problem says she buys twice the amount available, which must be the initial amount. So if x is the original, then she buys 2x. Given that 2x = 200, so x=100. So the store starts with 100. She buys 200, totaling 300. Selling 3/4 (225) leaves 75. Then mother buys 300 more, making it 375. Then sells 150, so 225 left. Therefore, the correct answer is 225. This makes sense now. So after working through it step by step, considering the fractions and the purchases, the total remaining is 225.
# To solve the problem step by step, let's break down the information given and perform the necessary calculations:
#
# 1. **Eliza's Purchase:**
#    - Eliza buys 200 decorative bracelets.
#    - The problem states that this amount is twice the initial number of bracelets available.
#    - Therefore, if \( x \) is the initial number of bracelets, then \( 2x = 200 \).
#    - Solving for \( x \), we get \( x = 100 \).
#    - So, Eliza starts with 100 bracelets and buys 200 more, resulting in a total of \( 100 + 200 = 300 \) bracelets.
#
# 2. **Mother's Sale:**
#    - The mother sells \( \frac{3}{4} \) of the total bracelets available.
#    - Therefore, the number of bracelets sold is \( \frac{3}{4} \times 300 = 225 \).
#    - The number of bracelets remaining after the sale is \( 300 - 225 = 75 \).
#
# 3. **Mother's Additional Purchase and Sale:**
#    - The mother then buys an additional 300 bracelets.
#    - Adding these to the remaining 75 bracelets results in a total of \( 75 + 300 = 375 \) bracelets.
#    - The mother then sells 150 bracelets.
#    - Subtracting the sold bracelets from the total gives \( 375 - 150 = 225 \) bracelets remaining.
#
# Therefore, the total number of decorative bracelets left in the store is \(\boxed{225}\).<end_working_out><SOLUTION>225</SOLUTION>
# Extracted:
# 225
# ********************Question:
#  تیلی ۱۲۰ ستاره را در شرق خانه‌اش و شش برابر این تعداد را در غرب آن می‌شمارد. او در مجموع چند ستاره می‌شمارد؟
# Answer:
# ۸۴۰
# Response:
# Okay, let's see. The problem says that Telly counts 120 stars in the east part of his house and six times that amount in the west part. So, how do we find the total number of stars he's counted in total?
#
# First, the east part has 120 stars. That's straightforward. The west part has six times that number. So, we need to multiply 120 by 6. Let me calculate that. 120 multiplied by 6 would be 120 times 6.
#
# 120 times 6 is the same as 120 multiplied by 6, which is 720. So, the west part has 720 stars. Now, to find the total, we add the stars from both parts together. That means 120 (east) plus 720 (west).
#
# Let me add those two numbers. 120 + 720. Hmm, 120 plus 700 would be 820, then add the remaining 20, which gives 840. But wait, let me check that again. 120 plus 720 is indeed 840. So, the total number of stars is 840.
#
# Wait, let me make sure I didn't make a mistake with the multiplication. 6 times 120 is 6 x 120. Let's break it down: 6 x 100 is 600, and 6 x 20 is 120, so 600 + 120 = 720. Yep, that's correct. Therefore, adding the two parts, 120 + 720 equals 840. So, the answer should be 840. Telly counts 840 stars in total.
# To find the total number of stars Telly counts, we start by determining the number of stars in each part of his house.
#
# 1. The number of stars in the east part is given as 120.
# 2. The number of stars in the west part is six times the number of stars in the east part. Therefore, we calculate:
#    \[
#    6 \times 120 = 720
#    \]
# 3. To find the total number of stars, we add the number of stars in both parts:
#    \[
#    120 + 720 = 840
#    \]
#
# Thus, Telly counts a total of \(\boxed{840}\) stars.
# To find the total number of stars Telly counts, we start by determining the number of stars in each part of his house.
#
# 1. The number of stars in the east part is given as 120.
# 2. The number of stars in the west part is six times the number of stars in the east part. Therefore, we calculate:
#    \[
#    6 \times 120 = 720
#    \]
# 3. To find the total number of stars, we add the number of stars in both parts:
#    \[
#    120 + 720 = 840
#    \]
#
# Thus, Telly counts a total of \(\boxed{840}\) stars.
# Extracted:
# None
# ********************Question:
#  کارن ۵۰ کوکی شکلاتی می‌پزد. او ۱۰ تا از آنها را برای خودش نگه می‌دارد و ۸ تا را به پدربزرگ و مادربزرگش می‌دهد. اگر کارن بخواهد به همه بچه‌های کلاسش کوکی بدهد و کلاسش ۱۶ نفر باشد، به هر نفر چند کوکی می‌رسد؟
# Answer:
# ۲
# Response:
# Okay, let's see here. So the problem is that Karen bakes 50 chocolate cookies. She keeps 10 of them for herself and gives 8 to her grandparents. Now she wants to share the rest with all the 16 kids in her class. We need to find out how many cookies each kid gets.
#
# First, I need to figure out how many cookies are left after Karen takes some for herself and gives some to her grandparents. So if she baked 50, minus the 10 she kept, that's 40 left. Then subtract the 8 she gave to her grandparents. Let me do that calculation. 50 minus 10 is 40, minus 8 would be 32. So 32 cookies are left for the class.
#
# Now, there are 16 kids in the class. So each kid would get 32 divided by 16. Let me recall how 16 times 2 is 32. Yep, 16 multiplied by 2 equals 32. So dividing 32 by 16 is 2. Therefore, each kid gets 2 cookies.
#
# Wait, let me check that again to make sure I didn't make a mistake. Original amount: 50. She took 10: 50-10=40. Then gave 8 to grandparents: 40-8=32. Then divided by 16 kids: 32/16=2. That seems right. So the answer should be 2. I don't think there's any other step here. So the solution is 2 cookies per child.
# To determine how many cookies each child in Karen's class receives, follow these steps:
#
# 1. **Total Cookies Baked**: Karen bakes 50 chocolate cookies.
# 2. **Cookies Kept by Karen**: She keeps 10 cookies for herself.
# 3. **Cookies Given to Grandparents**: She gives 8 cookies to her grandparents.
# 4. **Cookies Remaining for the Class**: Calculate the remaining cookies after the above actions.
#    \[
#    50 - 10 - 8 = 32
#    \]
# 5. **Number of Children in the Class**: There are 16 children in her class.
# 6. **Cookies per Child**: Divide the remaining cookies by the number of children.
#    \[
#    \frac{32}{16} = 2
#    \]
#
# Thus, each child gets \(\boxed{2}\) cookies.
# To determine how many cookies each child in Karen's class receives, we can follow these steps:
#
# 1. **Calculate the remaining cookies after Karen's personal and grandparents' shares:**
#    \[
#    50 - 10 - 8 = 32
#    \]
#    So, there are 32 cookies left for the class.
#
# 2. **Divide the remaining cookies by the number of children in the class:**
#    \[
#    \frac{32}{16} = 2
#    \]
#
# Therefore, each child gets \(\boxed{2}\) cookies.<end_working_out><SOLUTION>2</SOLUTION>
# Extracted:
# 2
# ********************Question:
#  تاس و دوستانش یک تی‌شرت برای فروش گذاشتند. آنها در عرض ۲۵ دقیقه ۲۰۰ تی‌شرت فروختند. نیمی از تی‌شرت‌ها مشکی و ۳۰ دلار قیمت داشتند، در حالی که نیمی دیگر سفید و ۲۵ دلار قیمت داشتند. آنها در هر دقیقه از این فروش چقدر درآمد داشتند؟
# Answer:
# ۲۲۰
# Response:
# Okay, let's see. They sold 200 T-shirts in 25 minutes. Half of them were black, priced at $30 each, and the other half were white, priced at $25 each. The question is asking how much they earned per minute.
#
# First, I need to find the total earnings from the black T-shirts. Since half of 200 is 100, there were 100 black ones. Each black T-shirt is $30, so 100 * 30 would be 3000 dollars total for the black ones.
#
# Next, the white T-shirts. Another 100 white ones, each priced at $25. So 100 * 25 is 2500 dollars for the white ones.
#
# Adding those two totals together, 3000 + 2500 equals 5500 dollars total earnings.
#
# Now, they sold all that in 25 minutes. So to find the earnings per minute, divide the total by 25. 5500 divided by 25. Let me calculate that.
#
# 25 times 200 is 5000. 5500 minus 5000 is 500. 25 multiplied by 20 (which is 500) is 500. So 25*20=500, and 25*200=5000, add them together is 5500. So 25*(200/25 +20/25)=5500. Wait, or simply 5500 divided by 25. 25 goes into 55 twice (50), remainder 5. Bring down the next zero. 25 goes into 50 twice, so 5500 divided by 25 is 220.
#
# So they earned 220 dollars per minute.
# To determine how much John and his friends earned per minute from selling the T-shirts, we start by calculating the total number of T-shirts sold and their respective prices.
#
# 1. **Calculate the number of black and white T-shirts:**
#    - Total T-shirts sold: 200
#    - Number of black T-shirts: \( \frac{200}{2} = 100 \)
#    - Number of white T-shirts: \( \frac{200}{2} = 100 \)
#
# 2. **Calculate the total earnings from black T-shirts:**
#    - Price per black T-shirt: $30
#    - Total earnings from black T-shirts: \( 100 \times 30 = 3000 \) dollars
#
# 3. **Calculate the total earnings from white T-shirts:**
#    - Price per white T-shirt: $25
#    - Total earnings from white T-shirts: \( 100 \times 25 = 2500 \) dollars
#
# 4. **Calculate the total earnings from both types of T-shirts:**
#    - Total earnings: \( 3000 + 2500 = 5500 \) dollars
#
# 5. **Calculate the earnings per minute:**
#    - Total time taken: 25 minutes
#    - Earnings per minute: \( \frac{5500}{25} = 220 \) dollars
#
# Thus, John and his friends earned \(\boxed{220}\) dollars per minute.<end_working_out><SOLUTION>220</SOLUTION>
# Extracted:
# 220
# ********************Question:
# آذوقه کافی در قلعه‌ای وجود دارد که می‌تواند ۳۰۰ نفر را به مدت ۹۰ روز سیر کند. پس از ۳۰ روز، ۱۰۰ نفر قلعه را ترک می‌کنند. چند روز دیگر تا تمام شدن تمام آذوقه باقی مانده است؟
# Answer:
# ۹۰
# Response:
# Okay, let's see. The problem is about food supplies in a fortress. Initially, there's enough food for 300 people for 90 days. After 30 days, 100 people leave. I need to find out how many more days the remaining food will last.
#
# First, I need to figure out the total amount of food available in terms of person-days. A person-day is one person consuming food for one day. So, if the food can feed 300 people for 90 days, the total food is 300 * 90 = 27,000 person-days.
#
# Now, after 30 days, the food consumed would be 300 people * 30 days = 9,000 person-days. Subtracting that from the total gives the remaining food: 27,000 - 9,000 = 18,000 person-days.
#
# After 30 days, 100 people leave, so the remaining population is 300 - 100 = 200 people. Now, I need to find out how many days the remaining 18,000 person-days will last for 200 people. That would be the total remaining food divided by the number of people: 18,000 / 200.
#
# Let me calculate that: 18,000 divided by 200 is 90. So, the food will last for 90 more days after the others leave.
#
# I think that's the answer. Let me check if there's any other step I missed. The problem states that after 30 days, 100 people leave. So, the first 30 days they were all 300 people. Then, there's a reduction to 200 people. The remaining food is enough for them for another 90 days. Yeah, that seems right. So the answer should be 90 days.
# To solve the problem, we start by calculating the total amount of food available in person-days. Given that the food can feed 300 people for 90 days, the total food supply is:
#
# \[ 300 \text{ people} \times 90 \text{ days} = 27000 \text{ person-days} \]
#
# After 30 days, the food consumed by the 300 people is:
#
# \[ 300 \text{ people} \times 30 \text{ days} = 9000 \text{ person-days} \]
#
# Thus, the remaining food after 30 days is:
#
# \[ 27000 \text{ person-days} - 9000 \text{ person-days} = 18000 \text{ person-days} \]
#
# After 30 days, 100 people leave the fortress, leaving 200 people. To determine how many more days the remaining food will last for these 200 people, we divide the remaining food by the number of people:
#
# \[ \frac{18000 \text{ person-days}}{200 \text{ people}} = 90 \text{ days} \]
#
# Therefore, the remaining food will last for \(\boxed{90}\) more days.<end_working_out><SOLUTION>90</SOLUTION>
# Extracted:
# 90
# ********************Question:
#  ماریا فروشگاهی پیدا کرد که ژاکت‌های دست‌ساز را به قیمت ۳۰ دلار و یک روسری دست‌ساز را به قیمت ۲۰ دلار می‌فروشد. او می‌خواهد برای همه اعضای خانواده‌اش یکی بخرد. او ۶ ژاکت و ۶ روسری خواهد خرید. اگر او ۵۰۰ دلار پس‌انداز کرده باشد، پس از خرید همه اینها چقدر در پس‌انداز او باقی می‌ماند؟
# Answer:
# ۲۰۰
# Response:
# Okay, let's see. The problem is about Maria who found a store selling handmade jackets for $30 each and handmade scarves for $20 each. She wants to buy one for each family member, so she needs 6 jackets and 6 scarves. She has saved $500, and we need to find out how much she has left after the purchase.
#
# First, let's calculate the total cost of the jackets. Since each jacket is $30 and she needs 6, that would be 30 times 6. Let me compute that. 30 multiplied by 6 is 180. So, the jackets cost $180.
#
# Next, the scarves. Each scarf is $20, and she needs 6. So, 20 times 6. Let's calculate that. 20 multiplied by 6 is 120. Therefore, the scarves cost $120.
#
# Now, to find the total expenditure, we add the cost of the jackets and the scarves. So, 180 plus 120. Adding those together gives 300. Wait, that seems a bit low. Let me check again. 30*6 is 180, which is correct. 20*6 is 120, also correct. 180 + 120 is 300. Yeah, that seems right.
#
# So, the total cost is $300. She started with $500. To find out how much is left, subtract the total cost from her savings. So, 500 minus 300. That's 200. So, Maria should have $200 left after the purchase.
#
# Wait, let me make sure I didn't make a mistake with the multiplication. 30*6, remember that's 3 groups of 30 added together. 30+30+30 would be 81+81=81+81=160, wait no, 30+30=60, 60+30=90. So 3 times 30 is 90. yes, correct. 30*6=180. Correct. 20*6, again 2 groups of 30 (which is 60) plus another 2 groups of 30 (another 60), so 60+60=120. So 20*6 is 120. Adding them, 180 + 120 is 300. Yep, that's right. So 500-300=200. So the answer should be $200.
# Hey, let's see, Maria needs to buy 6 jackets at $30 each and 6 scarves at $20 each. So first, calculate the cost of the jackets. If each jacket is $30, then 6 jackets would be 30 multiplied by 6. Let me do that: 30 times 6 is 180. So the jackets total $180.
#
# Next, the scarves. Each scarf is $20, so 6 scarves would be 20 times 6. 20 multiplied by 6 is 120. So the scarves total $120.
#
# Now, add the two amounts to find the total cost: 180 + 120. Let's add those: 180 plus 120 is 300. So the total cost is $300.
#
# Maria has $500 saved. Subtract the total cost from her savings to find out how much is left: 500 minus 300. 500 - 300 equals 200. So she has $200 left after the purchase.
#
# Wait, let me double-check the calculations to be sure. 30*6: 3*6=18, so 180. Yep. 20*6: 20 times 6 is 120. Adding 180 and 120 gives 300. Then 500 - 300 is 200. So the answer should be 200. Let me just make sure there aren't any other factors. The problem states she's buying one per family member, so 6 each. So that seems correct. So the final answer is $200.
# الحل الصحيح هو با ضرب 30 في 6 للحصول على 180 دولار لفروشات الزي، وضرب 20 في 6 للحصول على 120 دولار لفروشات الكستنائيات، ثم جمع 180 و120 للحصول على مجموع مبيعات 300 دولار. بعد ذلك، نطرح 300 من 500 لنجدهم سيملكون 200 دولار بعد إلغاء المبيعات. وبالتالي، عدد الأرز ستكون 200.<end_working_out><SOLUTION>200</SOLUTION>
# Extracted:
# 200
# ********************Question:
#  لولا ۱۳ مینی کاپ کیک، ۱۰ پاپ تارت و ۸ پای بلوبری پخت. در همین حال، لولو ۱۶ مینی کاپ کیک، ۱۲ پاپ تارت و ۱۴ پای بلوبری درست کرد. لولا و لولو روی هم رفته چند شیرینی درست کرده‌اند؟
# Answer:
# ۷۳
# Response:
# Okay, let's see. The problem says that Leila baked 13 muffins, 10 pie tarts, and 8 blueberry pies. Then, Lolo, who's maybe a sibling or something, made 16 muffins, 12 pie tarts, and 14 blueberry pies. The question is asking how many desserts they made together.
#
# So, I need to find the total number of each type of dessert they made and then add those numbers up. Let me break it down by category.
#
# First, moufins: Leila made 13, Lolo made 16. Adding those together should give the total number of muffins.
#
# Wait, "moufins"? Hmm, maybe that's a typo? Maybe they meant "muffins"? Because muffins is plural of muffin. Let me check the problem again. Oh, original text has "۱۳ مینی کاپ کیک" which is "13 mini cakes." So even though the word has "i" not "p" in the middle, maybe "moufins" was a typo. Yeah, so "mini cakes" would be "muffins" in English. So mini muffins? Maybe? But the problem uses "mini מאפיות" which in Hebrew is "moufins" but the English term is "muffins." So even though the spelling is different, the meaning is the same. Okay, so 13 muffins Leila made, 16 Lolo made. 13 plus 16 would be 29 muffins.
#
# Next, pie tarts. Leila made 10, Lolo made 12. 10 plus 12 is 22 pie tarts.
#
# Then, blueberry pies. Leila had 8, Lolo made 14. 8 plus 14 is 22 blueberry pies.
#
# So now, summing those all up. Muffins 29, pie tarts 22, blueberry pies 22. Let's add them step by step. 29 and 22: Let me calculate that. 20 + 22 is 42, then 29 is 1 more than 28, so 42 +1 is 43. Then, take that 43 and add the 22 blueberry pies. 43 plus 22. Let's add the tens first: 40 + 20 is 60. Then 3 + 2 is 5. So 65. Therefore, the total number is 65.
#
# Wait, let me make sure I didn't mix up any numbers. Leila: 13 muffins, 10 pie tarts, 8 blueberries. That adds up to 13+10=23, 23+8=31. Lolo: 16 muffins, 12 pie tarts, 14 blueberries. That's 16+12=28, 28+14=42. So in total, 31+42=73. Oh, that's different from my previous answer. I must have made a mistake earlier. Let me check again.
#
# Original problem: Leila baked 13, 10, 8. Lolo baked 16, 12, 14. So Leila's total is 13+10+8=31. Lolo's total is 16+12+14=42. 31+42=73. So the correct total is 73. I think that's right.
# To determine the total number of desserts Leila and Lolo made together, we need to sum the quantities of each type of dessert they baked.
#
# First, we list the quantities:
# - Leila baked 13 muffins, 10 pie tarts, and 8 blueberry pies.
# - Lolo baked 16 muffins, 12 pie tarts, and 14 blueberry pies.
#
# Next, we calculate the total number of each type of dessert:
#
# 1. **Muffins**:
#    - Leila: 13
#    - Lolo: 16
#    - Total muffins: \(13 + 16 = 29\)
#
# 2. **Pie tarts**:
#    - Leila: 10
#    - Lolo: 12
#    - Total pie tarts: \(10 + 12 = 22\)
#
# 3. **Blueberry pies**:
#    - Leila: 8
#    - Lolo: 14
#    - Total blueberry pies: \(8 + 14 = 22\)
#
# Now, we sum the totals of all the desserts:
# \[
# 29 \text{ (muffins)} + 22 \text{ (pie tarts)} + 22 \text{ (blueberry pies)} = 73
# \]
#
# Thus, the total number of desserts Leila and Lolo made together is \(\boxed{73}\).<end_working_out><SOLUTION>73</SOLUTION>
# Extracted:
# 73
# ********************Question:
# جسی شنبه گذشته یازده جوک تعریف کرد و آلن هفت جوک. اگر تعداد جوک‌هایی که شنبه گذشته تعریف کردند را شنبه آینده دو برابر کنند، تا الان روی هم رفته چند جوک تعریف کرده‌اند؟
# Answer:
# ۵۴
# Response:
# Okay, let's try to figure this out. So, there's a problem about someone named جسی and another person named آلن who have been defining different types of things called جوک (I guess it's like types or definitions?). On a Saturday, جسی defined 11 types, and آلن defined 7. Then, the problem says that whoever defined the types on the previous Saturday (which was the one before the current one they mention) should double their number for the next Saturday. Now, we need to find the total number of types they have defined up to now.
#
# Hmm, alright. Let me break this down step by step. The problem mentions "شنبه گذشته" (last Saturday), these two people defined their types there. جسی did 11, and آلن did 7. Then it says, when they reach the next Saturday (the one being referred to as "آن زمان") they should double the number of the types from the previous Saturday. So, from the problem, it seems like they've already done the first Saturday's work, which is 11 and 7. Now, they need to double those and add them to the previous total.
#
# Wait, but let me make sure I understand the wording correctly. The problem is: "If the number of types they defined on the last Saturday is doubled for the next Saturday, how many types have been defined together up to now?" So, when they reach the next Saturday, they double the previous Saturday's count (which was 11 +7 = 18 for them together). So they would double that, which is 36, and then add that to the total from the previous two Saturdays to get the cumulative total.
#
# So step by step:
#
# - Last Saturday: جسی 11, آلن 7 → total = 18
# - Next Saturday: double that total (18*2) = 36
# - Cumulative total so far: last Saturday (18) + next Saturday (36) = 54
#
# So the answer should be 54. But let me check again if I interpreted the problem correctly. If the wording is "جسی شنبه گذشته یازده جوک تعریف کرد". So جسی defined 11 on the previous Saturday. اگر تعداد جوک‌هایی که شنبه گذشته تعریف کردند را شنبه آینده دو برابر کند. So the types defined on the previous Saturday (john defined 11, alain defined 7) would be 18. Then, they double that. So 18*2 = 36 next Saturday. Therefore, the total is 18 + 36 = 54. So the answer is 54. Yep, that seems right.
# To solve the problem, we need to track the number of types defined by جسی and آلن over two consecutive Saturdays.
#
# 1. On the previous Saturday (شنبه گذشته), جسی defined 11 types and آلن defined 7 types. Therefore, the total number of types defined on that Saturday is:
#    \[
#    11 + 7 = 18
#    \]
#
# 2. For the next Saturday (شنبه آینده), the number of types defined is doubled based on the previous Saturday's total. Thus, the number of types defined on the next Saturday is:
#    \[
#    2 \times 18 = 36
#    \]
#
# 3. The cumulative total number of types defined up to the next Saturday is the sum of the types defined on the previous Saturday and the next Saturday:
#    \[
#    18 + 36 = 54
#    \]
#
# Therefore, the total number of types defined together up to the next Saturday is:
# \[
# \boxed{54}
# \]<end_working_out><SOLUTION>54</SOLUTION>
# Extracted:
# 54
# ********************Question:
#  یک درخت سیب در یک فصل خاص ۲۰۰ سیب تولید کرد. این درخت در فصل بعد ۲۰٪ میوه کمتری تولید کرد، اما تولید میوه‌های درخت در فصل دوم در طول فصل سوم دو برابر شد. تعداد کل میوه‌هایی که درخت سیب در سه فصل رشد داده است را محاسبه کنید.
# Answer:
# ۶۸۰
# Response:
# Okay, let's see. The problem is about an apple tree that produces 200 apples in a certain season. Then, in the next season, it produces 20% fewer apples. But in the second season, the production doubles over the third season. We need to find the total number of apples over the three seasons.
#
# Right, so starting with the first season. That's straightforward: 200 apples.
#
# Next season, it's 20% fewer apples than the first season. So, how do I calculate that? If the original number is 200, 20% of that is 0.20 multiplied by 200, which is 40. So 200 minus 40 is 160. Therefore, the second season's production is 160 apples.
#
# Now, the tricky part is the third season. The problem says that the second season's production doubles over the third season. Wait, that doesn't make sense. Because if the second season produced 160, doubling that would be 320. But then how can the third season have a higher production than the second? That doesn't seem right. Maybe I misinterpreted the problem here.
#
# Wait, let me read the problem again. "تولید میوه‌های درخت در فصل دوم در طول فصل سوم دو برابر شد." So maybe it's saying that the production in the third season is double the second season's production? Not the other way around. Yeah, that makes more sense. So if second season is 160, then third season would be 2 times 160, which is 320.
#
# So now, adding all three seasons: first 200, second 160, third 320. Total would be 200 + 160 + 320. Let's calculate that. 200 plus 160 is 360. Then 360 plus 320 is 680. So the total number of apples over the three seasons is 680. Let me make sure I didn't make any mistakes here.
#
# First season: 200. Second season: 20% less than 200 is 160. Third season: double of 160 is 320. Adding them up: 200 + 160 = 360, 360 + 320 = 680. That seems right. So I think the answer is 680. Therefore, the total number of apples over the three seasons is 680.
# To find the total number of apples produced by the apple tree over three seasons, we will proceed step-by-step as follows:
#
# 1. **First Season:**
#    The tree produces 200 apples.
#
# 2. **Second Season:**
#    The production is 20% less than the first season. To calculate this:
#    \[
#    \text{Reduction} = 0.20 \times 200 = 40 \text{ apples}
#    \]
#    \[
#    \text{Production in the second season} = 200 - 40 = 160 \text{ apples}
#    \]
#
# 3. **Third Season:**
#    The production is double that of the second season. Therefore:
#    \[
#    \text{Production in the third season} = 2 \times 160 = 320 \text{ apples}
#    \]
#
# 4. **Total Production:**
#    Adding the production from all three seasons:
#    \[
#    \text{Total production} = 200 + 160 + 320 = 680 \text{ apples}
#    \]
#
# Thus, the total number of apples produced by the tree over the three seasons is \(\boxed{680}\).<end_working_out><SOLUTION>680</SOLUTION>
# Extracted:
# 680
# ********************Question:
# آوا ۹ درخت سیب در حیاط خلوت خود کاشت. این ۳ درخت بیشتر از تعداد درخت سیبی است که لیلی در حیاط خلوت خود کاشته بود. آنها روی هم رفته چند درخت سیب در حیاط خلوت خود کاشتند؟
# Answer:
# ۱۵
# Response:
# Okay, let's see. The problem says that Ali planted 9 apple trees in his backyard. Then it mentions that these 3 are more than the number of apple trees Lili had planted. So, how many trees did they plant together? Hmm, let's break it down step by step.
#
# First, Ali has 9 apple trees. The problem states that the 3 trees are more than Lili's. Wait, 3 trees more than Lili's? But if Ali has 9 trees, and those 3 are more than Lili's, then Lili must have planted 6 trees because 9 minus 3 is 6. So Lili has 6 trees.
#
# Now, to find out how many they have together, we just add Ali's trees to Lili's trees. 9 plus 6. Let me calculate that. 9 and 6. Adding the ones place: 9 + 6 = 15. So the total number of trees they have in the backyard is 15.
#
# Wait, let me check if that makes sense. If Lili has 6 trees, and the problem says the three trees are more than Lili's, then 9 being more than 6 would be correct. Yes, that checks out. So adding 9 and 6 gives 15. So the answer should be 15. Let me make sure I didn't confuse the numbers. The problem says "these 3 trees" are more than Lili's. But wait, does that mean the three trees are in addition to Lili's? Wait, read it again. "These 3 are more than the number of apple trees that Lili had planted." So it's implying that Lili had some, and the three trees (which are part of Ali's 9) are more than her number. So Lili's number must be less than 3? Wait, no, that would make sense if Lili had, say, 2 trees. 3 is more than 2. So if the three trees are in Ali's total of 9, then Lili has 2 trees. So 9 - 3 = 6? Wait, no. If the three are more than Lili's, then Lili has fewer than 3. So if Lili has 2, 3 is more than 2. Then Ali has 6 trees (because 3 more than Lili's 3 would be 6), but Wait, the problem says "these 3" are more than Lili's, which implies Lili has less than 3. So if Lili has 2, then 3 is more than 2. Then Ali has 9, which means the total would be 2 + 9 = 11. Wait, but the problem says "these 3 are more than Lili's," so Lili's total must be less than 3. So if Lili has 2, then 2 is less than 3. Then Ali has 3 more than Lili's, so Lili has 2, Ali has 5 (2+3). But the problem says Ali has 9 trees. So that can't be right. I must have misinterpreted. Let me think again.
#
# Wait, the problem is: "آلی ۹ درخت سیب در حیاط خلوت خود کاشت. این ۳ درخت بیشتر از تعداد درخت سیبی است که لیلی در حیاط خلوت خود کاشته بود. آنها روی هم رفته چند درخت سیب در حیاط خلوت خود کاشتند؟"
#
# So it says that the 3 trees are more than Lili's. So if the 3 trees are part of the 9, then Lili has fewer than 3. So Lili has 2, then the 3 in Ali's trees would be more than Lili's 2. Then Ali has 2 + 3 = 5 trees? But the problem says Ali has 9. So that's a contradiction. So maybe the problem means that the three trees are additional to what Lili has. So perhaps Lili has some trees, and then Ali picks 3 more, making a total of 9. Wait, let me parse it again.
#
# It says "این ۳ درخت بیشتر از تعداد درخت سیبی است که لیلی در حیاط خلوت خود کاشته بود." So the 3 trees are more than the number Lili had. So if Lili had x trees, then x < 3. So Lili has at most 2 trees. Then Ali has 9 trees, which is composed of these 3 more than her and possibly others. Wait, but the problem doesn't mention Lili planting more than her initial trees. So maybe Lili has 2 trees, and the 3 in Ali's 9 are more than her 2. So Lili has 2, then 2 + 3 = 5, but Ali has 9. So total 2 + 9 = 11. But the problem says "آنها روی هم رفته چند درخت سیب در حیاط خلوت خود کاشتند؟" which is "how many trees in total did they plant?" So 2 (Lili) + 9 (Ali) = 11. So the answer is 11.
#
# Wait, but let me check the wording again. The problem states that the three trees are more than Lili's. So if Lili has n trees, then 3 > n. So n could be 2, 1, or 0. But assuming they both have at least one tree, maybe Lili has 2. Then Ali has 3 more than Lili's, so 2 + 3 = 5 trees. But the problem says Ali has 9. So that's not working. Maybe the problem is saying that Ali's 9 trees include those 3 that are more than Lili's. So maybe Lili has some trees, and then 3 more of Ali's trees exceed her count. So if Lili has x, then 3 > x, so x < 3. Then Ali has 9, which includes those 3. So total trees would be x (Lili's) + 9 = x + 9. Since 3 > x, then x can be 2, 1, or 0. If Lili has 2, then total is 2+9=11. If she has 1, total is 10. If 0, total is 9. The problem doesn't specify Lili's initial number, but since they are both planting trees, it's likely they have at least one each. So perhaps Lili has 2 trees. Then the answer is 2 + 9 = 11. So the answer is 11. Let me confirm that again. If Lili has 2, then the 3 trees that are more than her are in the 9 that Ali has. So if Lili has 2, then those three are additional. So total Ali has 9, 3 of which are more than her 2. So Lili has 2, Ali has 7 others plus those 3. Wait, no. If the three are more than her, then those three are part of Ali's 9. So if Lili has 2, then those 3 are more (i.e., 3 > 2). So total trees would be 2 +9 =11. Yeah, that makes sense. The problem doesn't specify that Ali's 9 are all additional, but given the wording, it's implying that those three exceed Lili's count. So if Lili has 2, then the 3 in the 9 are more than her 2, so 2 +3 in the 9 would be 5, but the problem says Ali has 9. So that doesn't align. Wait, maybe the problem means that in the 9, 3 are more than Lili's, so subtract 3 from Ali's total to get Lili's as 6. For example, if Lili has 6, then 3 more is 9
# Extracted:
# None
# ********************Question:
#  کلی ۵ روز در هفته پنیر رشته‌ای را در ناهار فرزندانش قرار می‌دهد. فرزند بزرگترش هر روز ۲ عدد و فرزند کوچکترش فقط ۱ عدد پنیر رشته‌ای می‌خواهد. بسته‌ها شامل ۳۰ عدد پنیر رشته‌ای در هر بسته هستند. کلی برای ۴ هفته به چند بسته پنیر رشته‌ای نیاز دارد؟
# Answer:
# ۲
# Response:
# Okay, let's see. The problem is about calculating how many packages of string cheese Kim needs for her children over four weeks. Each week, they eat string cheese for dinner, and the older child wants 2 per day while the younger one wants 1. Each package contains 30 pieces. Alright, let's break this down step by step.
#
# First, I need to find out how much string cheese they consume each week. Since they have it 5 days a week, right? Each day:
#
# Older child: 2 pieces
# Younger child: 1 piece
#
# So per day, that's 2 + 1 = 3 pieces. Then for 5 days a week, 3 pieces/day times 5 days would be 15 pieces per week. Wait, but let me verify that. Let's say Sunday to Friday, which are 5 days. 2+1 is 3, 3 times 5 is 15. Yep, that makes sense.
#
# Now, four weeks: 15 pieces/week times 4 weeks. Let me calculate that. 15 times 4 is 60 pieces in total. So they need 60 pieces over four weeks.
#
# Each package has 30 pieces. So how many packages are needed? 60 divided by 30. Let's do that division. 30 goes into 60 exactly two times. So 2 packages. Wait, is that right? Let me check again.
#
# Alternative way: How many days? 5 days a week. 4 weeks would be 5*4=20 days. Each day they eat 3 pieces. So 3*20=60. Yep, still 60 pieces. Then 60/30 is 2. So two packages.
#
# Hmm, seems straightforward. Let me just make sure I didn't miss any days. If Kim has 5 days a week, and 4 weeks, that's 20 days. Three pieces each day, so 20*3=60. Each package is 30, so 60/30=2. Yep, that's right. So the answer should be 2 packages. Did I make any mistakes? Let me think again. The wording is they have it for dinner each week, 5 days, so yes. Older grabbing 2 each day, younger 1. So each day 3. 5 days a week, 15. 4 weeks that's 60. 30 per package, so 60/30=2. I think that's correct. So the answer is 2 packages. Let me just write that down.
# To determine how many packages of string cheese Kim needs for her children over four weeks, we start by calculating the total consumption per week and then over the entire period.
#
# First, we note that the children eat string cheese 5 days a week. The older child consumes 2 pieces per day, and the younger child consumes 1 piece per day. Therefore, the total consumption per day is:
# \[ 2 + 1 = 3 \text{ pieces per day} \]
#
# Next, we calculate the weekly consumption:
# \[ 3 \text{ pieces per day} \times 5 \text{ days per week} = 15 \text{ pieces per week} \]
#
# For four weeks, the total consumption is:
# \[ 15 \text{ pieces per week} \times 4 \text{ weeks} = 60 \text{ pieces} \]
#
# Each package contains 30 pieces of string cheese. To find the number of packages needed, we divide the total consumption by the number of pieces per package:
# \[ \frac{60 \text{ pieces}}{30 \text{ pieces per package}} = 2 \text{ packages} \]
#
# Thus, Kim needs \(\boxed{2}\) packages of string cheese for four weeks.<end_working_out><SOLUTION>2</SOLUTION>
# Extracted:
# 2

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained! First, let's first try the model without any GRPO trained:

# %%
text = "What is the sqrt of 101?"

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 1.0,
    top_k = 50,
    max_tokens = 1024,
)
output = model.fast_generate(
    [text],
    sampling_params = sampling_params,
    lora_request = None,
)[0].outputs[0].text

output

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Verify LoRA is actually trained!

# %%
from safetensors import safe_open

tensors = {}
with safe_open("grpo_saved_lora/adapter_model.safetensors", framework = "pt") as f:
    # Verify both A and B are non zero
    for key in f.keys():
        tensor = f.get_tensor(key)
        n_zeros = (tensor == 0).sum() / tensor.numel()
        assert(n_zeros.item() != tensor.numel())

# %% [markdown]
# Now we load the LoRA and test:

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user",   "content": "What is the sqrt of 101?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
    tokenize = False,
)
from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 1.0,
    top_k = 50,
    max_tokens = 2048,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output

# %%
huggingface-cli login

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

repo_id = "your-username/your-model-name"

model.push_to_hub(repo_id)
tokenizer.push_to_hub(repo_id)

# %% [markdown]
# Our reasoning model is much better - it's not always correct, since we only trained it for an hour or so - it'll be better if we extend the sequence length and train for longer!

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens. See [our docs](https://unsloth.ai/docs/basics/inference-and-deployment) for more deployment options.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("qwen_finetune_16bit", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("HF_USERNAME/qwen_finetune_16bit", tokenizer, save_method = "merged_16bit", token = "YOUR_HF_TOKEN")

# Merge to 4bit
if False: model.save_pretrained_merged("qwen_finetune_4bit", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("HF_USERNAME/qwen_finetune_4bit", tokenizer, save_method = "merged_4bit", token = "YOUR_HF_TOKEN")

# Just LoRA adapters
if False:
    model.save_pretrained("qwen_lora")
    tokenizer.save_pretrained("qwen_lora")
if False:
    model.push_to_hub("HF_USERNAME/qwen_lora", token = "YOUR_HF_TOKEN")
    tokenizer.push_to_hub("HF_USERNAME/qwen_lora", token = "YOUR_HF_TOKEN")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [docs page](https://unsloth.ai/docs/basics/inference-and-deployment/saving-to-gguf)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("qwen_finetune", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("HF_USERNAME/qwen_finetune", tokenizer, token = "YOUR_HF_TOKEN")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("qwen_finetune", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("HF_USERNAME/qwen_finetune", tokenizer, quantization_method = "f16", token = "YOUR_HF_TOKEN")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("qwen_finetune", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("HF_USERNAME/qwen_finetune", tokenizer, quantization_method = "q4_k_m", token = "YOUR_HF_TOKEN")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "HF_USERNAME/qwen_finetune", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "YOUR_HF_TOKEN",
    )

# %% [markdown]
# Now, use the `qwen_finetune.Q8_0.gguf` file or `qwen_finetune.Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 4. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://unsloth.ai/docs/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
#
#   This notebook and all Unsloth notebooks are licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
